# %% [markdown]
# *Pendant les 3 premières séances de TP, nous allons mettre en pratique certaines des méthodes présentées en cours pour détecter des objets dans une image.*

# %% [markdown]
# # Localisation et classification d'objet

# %% [markdown]
# ## Introduction
#
# Dans cette partie, nous allons nous concentrer sur le problème de la localisation d'un seul objet par classe. La base de données a été épurée pour se concentrer uniquement sur ce cas.
#
# En localisation et détection, on cherche à déterminer la position d'un objet, ainsi que sa classe, sous la forme d'une boîte englobante de largeur $b_w$ et hauteur $b_h$, et dont le centre a pour coordonnées le point $(b_x, b_y)$.
#
# <center> <img src="https://drive.google.com/thumbnail?id=1_jHHv6ZDe-3Xz25jIZ6o177laBEfmMRR&sz=w1000" style="width:500;height:300px;"></center>
# <caption><center> Figure 1: Modèle de boîte englobante utilisé pour la localisation </center></caption>
#
# Le problème de localisation considère qu'un seul objet est présent sur l'image, alors que le problème de détection cherche à déterminer l'ensemble des objets présents sur l'image.
#
#
#
# Pour commencer, récupérez les images de la base de données :

# %%
# !git clone https://github.com/axelcarlier/mangeoires_loc.git
# Out:
# fatal: destination path 'mangeoires_loc' already exists and is not an empty directory.

# %% [markdown]
# La base de données consiste en des photographies prises par une caméra reliée à une Raspberry Pi, cachée dans une mangeoire. Plusieurs mangeoires sont disséminées dans la nature en Occitanie, et l'objectif de [ce projet](https://econect.cnrs.fr/) est la reconnaissance des espèces et le comptage des individus qui viennent se poser devant le caméra, afin de suivre l'évolution des populations d'oiseaux et ainsi monitorer la biodiversité.
#
# La base de données qui vous est fournie regroupe 11 espèces d'animaux, majoritairement des oiseaux, désignés par un code :
#
# 1. Mésange charbonnière (**MESCHA**)
# 2. Verdier d'Europe (**VEREUR**)
# 3. Écureuil roux (**ECUROU**)
# 4. Pie bavarde (**PIEBAV**)
# 5. Sittelle torchepot (**SITTOR**)
# 6. Pinson des arbres (**PINARB**)
# 7. Mésange noire (**MESNOI**)
# 8. Mésange nonnette (**MESNON**)
# 9. Mésange bleue (**MESBLE**)
# 10. Rouge-gorge (**ROUGOR**)
# 11. Accenteur mouchet (**ACCMOU**)
#
# <center>
# <img src="https://drive.google.com/thumbnail?id=1Eit86N4D0Ea7ai1rBa0o-GmTwckhP9i0&sz=w1000" width=200>
# <img src="https://drive.google.com/thumbnail?id=1lC7WL93UqDT_KV2m21yx99N5dkf98nCY&sz=w1000" width=200>
# <img src="https://drive.google.com/thumbnail?id=10tzJORcSrSckDWmBDBtc8FUirxdbRxri&sz=w1000" width=200>
# <img src="https://drive.google.com/thumbnail?id=1IHZp_B6bc8bADtAReRHhcyOjDQZAXDBQ&sz=w1000" width=200> </center>
# <center><caption> Figure 2: Exemples d'images de la base de données </caption></center>

# %%
import PIL
from PIL import Image
import csv
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import utils
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split

print(tf.config.list_physical_devices('GPU'))
# Out:
# 2025-03-01 15:34:52.738975: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740839692.752935   89527 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740839692.756834   89527 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-01 15:34:52.771829: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Préparation des données
#
# Le code ci-dessous permet de charger les données et les formater pour la classification. Prenez le temps de regarder un peu le format des labels $y$.
# Notez que les images sont rendues carrées lors du chargement.

# %%
# Lecture du CSV contenant les informations relatives à la base de données
dataset = []
with open('mangeoires_loc/bd_mangeoires_equilibre.csv', newline='') as csvfile:
	filereader = csv.reader(csvfile, delimiter=' ', quotechar='|')
	for row in filereader:
		data = row[0].split(',')
		if data[0] != 'Data':
			box = [float(data[5]), float(data[6]), float(data[7]), float(data[8])]
			new_entry = {'type': data[0], 'specie': data[1], 'path': data[2], 'shape': [float(data[3]), float(data[4])], 'box': box}
			dataset.append(new_entry)

# Nombre de classes de la base de données et intitulé des classes
class_labels = list(dict.fromkeys([item['specie'] for item in dataset]))
num_classes = len(class_labels)

# Extraction des données d'apprentissage et de test
dataset_train = [item for item in dataset if item['type']=='TRAIN']
dataset_test = [item for item in dataset if item['type']=='TEST']

print(class_labels)
# Out:
# ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']

# %%
def build_localization_tensors(image_size, dataset, num_classes):
  # Préparation des structures de données pour x et y
  x = np.zeros((len(dataset), image_size, image_size, 3))
  y = np.empty((len(dataset), num_classes + 5)) # 1 + 4 + num_classes : présence / boîte englobante / classes

  # Compteur de parcours du dataset
  i = 0

  for item in dataset:
    # Lecture de l'image
    img = Image.open('mangeoires_loc/' + item['path'])
    # Mise à l'échelle de l'image
    img = img.resize((image_size,image_size), Image.Resampling.LANCZOS)
    # Remplissage de la variable x
    x[i] = np.asarray(img)

    y[i, 0] = 1 # Un objet est toujours présent !

    # Coordonnées de boîte englobante
    img_shape = item['shape']
    box = item['box']
    bx = (box[0] + (box[2] - box[0])/2)/img_shape[0]
    by = (box[1] + (box[3] - box[1])/2)/img_shape[1]
    bw = (box[2] - box[0])/img_shape[0]
    bh = (box[3] - box[1])/img_shape[1]
    y[i, 1] = bx
    y[i, 2] = by
    y[i, 3] = bw
    y[i, 4] = bh

    # Probabilités de classe, sous la forme d'une one-hot vector
    label = class_labels.index(item['specie'])
    classes_probabilities = keras.utils.to_categorical(label, num_classes=num_classes)
    y[i, 5:] = classes_probabilities

    i = i+1

  return x, y

# %% [markdown]
# Séparation des données d'entraînement pour extraire un ensemble de validation, et pré-traitement des données.

# %%
# Pour la suite du TP on considèrera des images de taille 64x64x3
# Augmenter cette valeur donnerait de meilleurs résultats mais nécessiterait des calculs plus long.
IMAGE_SIZE = 64

# Lecture des données d'entraînement et de test
x, y = build_localization_tensors(IMAGE_SIZE, dataset_train, num_classes)
x_test, y_test = build_localization_tensors(IMAGE_SIZE, dataset_test, num_classes)

#Extraction d'un ensemble de validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.10, random_state=42)

# Pour améliorer l'entraînement, on peut centrer-réduire les coordonnées des bounding boxes...
y_std = np.std(y_train, axis=0)
y_mean = np.mean(y_train, axis=0)
y_train[...,1:5] = (y_train[...,1:5] - y_mean[1:5])/y_std[1:5]
y_val[...,1:5] = (y_val[...,1:5] - y_mean[1:5])/y_std[1:5]
y_test[...,1:5] = (y_test[...,1:5] - y_mean[1:5])/y_std[1:5]

# ... et normaliser les valeurs de couleur
x_train = x_train/255
x_val = x_val/255
x_test = x_test/255

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# Une fonction de calcul de l'intersection sur union, qui nous sera utile pour les métriques d'évaluation de nos méthodes :
#
# $$ IoU (R_1, R_2) = \frac{\mathcal{A} (R_1 \cap R_2)}{\mathcal{A} (R_1 \cup R_2)} = \frac{\mathcal{A} (R_1 \cap R_2)}{\mathcal{A} (R_1) + \mathcal{A} (R_2) -  \mathcal{A} (R_1 \cap R_2)} $$
#
# <center>
# <img src="https://drive.google.com/thumbnail?id=1BQx2kDOCltZ_5gcnKVWTVUVNmGk-7qBC&sz=w1000" width=500>
# </center>

# %%
def intersection_sur_union(box1, box2):
  """
  Calcul de l'intersection sur union entre deux rectangles box1 et box2

  Arguments:
  box1, box2 -- les coordonnées des deux rectangles, chacun sous la forme [cx, cy, w, h]
                où (cx, cy) désigne les coordonnées du centre du rectangle,
                w sa largeur et h sa hauteur

  Retourne :
  iou -- la valeur d'intersection sur union entre les deux rectangles
  """
  x1 = box1[0] - box1[2]/2;
  x2 = box1[0] + box1[2]/2;
  x3 = box2[0] - box2[2]/2;
  x4 = box2[0] + box2[2]/2;
  y1 = box1[1] - box1[3]/2;
  y2 = box1[1] + box1[3]/2;
  y3 = box2[1] - box2[3]/2;
  y4 = box2[1] + box2[3]/2;
  area_inter = abs(max(x1,x3) - min(x2,x4)) * abs(max(y1,y3) - min(y2,y4))
  area_1 = abs(x1 - x2) * abs(y1 - y2)
  area_2 = abs(x3 - x4) * abs(y3 - y4)
  return area_inter / (area_1 + area_2 - area_inter)

# %% [markdown]
# Exécutez le bloc suivant pour vérifier votre implémentation :

# %%
print(intersection_sur_union([2.5, 2, 1, 4], [2, 3, 4, 2]))  # Résultat attendu : 0.2
print(intersection_sur_union([2.5, 2, 1, 4], [5, 3, 4, 2]))  # Résultat attendu : 0.0
# Out:
# 0.2
# 0.0

# %% [markdown]
# On va maintenant calculer les différentes métriques :
#
# $$ P = \frac{TP}{TP + FP} $$
#
# $$ R = \frac{TP}{TP + FN} $$
#
# $$ F1 = \frac{2 * P * R}{P + R} $$
#
# où $TP$ désigne le nombre de vrais positifs, $FP$ le nombre de faux positifs, $FN$ le nombre de faux négatifs, $P$ la précision, $R$ le rappel et $F1$ le F1-score.
#
# On considère souvent qu'une détection est correcte si la classification est valide et que l'intersection sur union entre vérité terrain et prédiction est supérieure à 0.5 (on utilisera un seuil modifiable *iou_thres*).

# %%
# On considère souvent qu'une détection est correcte si la classification est valide et que
# l'intersection sur union entre vérité terrain et prédiction est supérieure à 0.5
def global_accuracy(y_true, y_pred, iou_thres=0.5):
  """
  Calcul, pour chaque classe de la précision, du rappel et du F1-score ainsi
  que du pourcentage global de bonnes détections.

  Arguments:
  y_true -- les labels de la vérité terrain, de dimension (M, 1+4+N) où M désigne
          le nombre d'éléments du dataset et N le nombre de classes (11 dans notre cas)
  y_pred -- les labels prédits par un modèle, de dimension (M, 1+4+N)
  iou_thres -- seuil d'intersection sur union entre une boîte "vérité-terrain" et
              une boite prédite au-dessus duquel on considère que la prédiction est correcte

  Retourne :
  class_res -- liste de longueur N contenant des dictionnaires sous la forme
            {"Précision": p, "Rappel": r, "F-score": f} résumant les métriques
            précision, rappel et F1-score pour chacune des classes.
  accuracy -- pourcentage global de bonnes détections
  """
  # Initialisation des métriques : nombre de vrais positifs (TP), faux positifs (FP)
  # et faux négatifs (FN) pour chaque classe
  class_metrics = []
  for i in range(num_classes):
    class_metrics.append({'TP': 0, 'FP': 0, 'FN': 0})

  # Nombres de détections correctes et de détections incorrectes
  total_correct_detections = 0
  toal_incorrect_detections = 0
  for i in range(y_true.shape[0]):
    # Labels vérité-terrain et prédits
    groundtruth_label = np.argmax(y_true[i,5:])
    predicted_label = np.argmax(y_pred[i,5:])

    # Coordonnées de boîtes englobantes réelles et prédites
    bx_true = (y_true[i,1]*y_std[1] + y_mean[1])
    by_true = (y_true[i,2]*y_std[2] + y_mean[2])
    bw_true = (y_true[i,3]*y_std[3] + y_mean[3])
    bh_true = (y_true[i,4]*y_std[4] + y_mean[4])
    bx_pred = (y_pred[i,1]*y_std[1] + y_mean[1])
    by_pred = (y_pred[i,2]*y_std[2] + y_mean[2])
    bw_pred = (y_pred[i,3]*y_std[3] + y_mean[3])
    bh_pred = (y_pred[i,4]*y_std[4] + y_mean[4])

    # Calcul de l'intersection sur union
    iou = intersection_sur_union([bx_true, by_true, bw_true, bh_true], [bx_pred, by_pred, bw_pred, bh_pred])

    ### A COMPLETER
    # Si la détection est correcte :
    if groundtruth_label == predicted_label and iou > iou_thres:
      # Mettre à jour le nombre de Vrais Positifs pour la classe vérité terrain :
      class_metrics[groundtruth_label]['TP'] += 1
    else:
      # Mettre à jour le nombre de Faux Positifs et/ou Faux Négatifs pour les
      # classes concernées
      if groundtruth_label != predicted_label:
        class_metrics[predicted_label]['FP'] += 1
        class_metrics[groundtruth_label]['FN'] += 1
      elif groundtruth_label == predicted_label and iou <= iou_thres:
        class_metrics[groundtruth_label]['FP'] += 1
        class_metrics[groundtruth_label]['FN'] += 1

  class_res = []
  for i in range(num_classes):
    # Pour chaque classe, on veut calculer Précision, Rappel et F1-Score à partir
    # des TP, FP et FN calculés sur le bloc précédent
    if class_metrics[i]['TP'] == 0 and class_metrics[i]['FP'] == 0:
      P = 0
    else:
      P = class_metrics[i]['TP'] / (class_metrics[i]['TP'] + class_metrics[i]['FP'])
    if class_metrics[i]['TP'] == 0 and class_metrics[i]['FN'] == 0:
      R = 0
    else:
      R = class_metrics[i]['TP'] / (class_metrics[i]['TP'] + class_metrics[i]['FN'])
    if P == 0 or R == 0:
      F_score = 0
    else:
      F_score = 2 / ((1/P) + (1/R))
    class_res.append({'Precision': P, 'Rappel': R, 'F-score': F_score})

  accuracy = (sum([class_metrics[i]['TP'] for i in range(num_classes)]) / y_true.shape[0]) * 100
  ### FIN
  return class_res, accuracy

# %%
num_class_test = 3
class_labels_test = ['Classe 1', 'Classe 2', 'Classe 3']
y_true_test = np.ones((num_class_test,8))
y_true_test[0,:2] = [0.5, 0.5]
y_true_test[0, 5:] = [1, 0, 0]
y_true_test[1,:2] = [0.5, 0.5]
y_true_test[1, 5:] = [0, 1, 0]
y_true_test[2,:2] = [0.5, 0.5]
y_true_test[2, 5:] = [0, 0, 1]
y_pred_test = np.ones((num_class_test,8))
y_pred_test[0,:2] = [0.6, 0.6]
y_pred_test[0, 5:] = [1, 0, 0]
y_pred_test[1,:2] = [2.5, 2.5]
y_pred_test[1, 5:] = [0, 0, 1]
y_pred_test[2,:2] = [0.6, 0.6]
y_pred_test[2, 5:] = [0, 0, 1]

class_res_test, acc_test = global_accuracy(y_true_test, y_pred_test)

print(f"La précision globale est de {acc_test:.1f}%")

print()
print("--------------------------------------------")
print("|  Classe  | Précision | Rappel | F1-score |")
print("--------------------------------------------")
for i in range(num_class_test):
  print(f"| {class_labels_test[i]:9s}|   {class_res_test[i]['Precision']:.2f}    |  {class_res_test[i]['Rappel']:.2f}  |   {class_res_test[i]['F-score']:.2f}   |")
  print("--------------------------------------------")
# Out:
# La précision globale est de 66.7%
#
# --------------------------------------------
# |  Classe  | Précision | Rappel | F1-score |
# --------------------------------------------
# | Classe 1 |   1.00    |  1.00  |   1.00   |
# --------------------------------------------
# | Classe 2 |   0.00    |  0.00  |   0.00   |
# --------------------------------------------
# | Classe 3 |   0.50    |  1.00  |   0.67   |
# --------------------------------------------

# %% [markdown]
# **Affichage attendu :**
# ```
# La précision globale est de 66.7%
#
# --------------------------------------------
# |  Classe  | Précision | Rappel | F1-score |
# --------------------------------------------
# | Classe 1 |   1.00    |  1.00  |   1.00   |
# --------------------------------------------
# | Classe 2 |   0.00    |  0.00  |   0.00   |
# --------------------------------------------
# | Classe 3 |   0.50    |  1.00  |   0.67   |
# --------------------------------------------
# ```

# %% [markdown]
# La fonction ci-dessous permet de calculer l'intersection sur union  sur des tenseurs (et non des tableaux numpy), elle sera donc utilisable comme métrique pendant l'entraînement.

# %%
def compute_iou(y_true, y_pred):
  ### "Dénormalisation" des coordonnées des boîtes englobantes
  pred_box_xy = y_pred[..., 0:2]* y_std[0:2] + y_mean[0:2]
  true_box_xy = y_true[..., 0:2]* y_std[0:2] + y_mean[0:2]

  ### "Dénormalisation" des largeur et hauteur des boîtes englobantes
  pred_box_wh = y_pred[..., 2:4] * y_std[2:4] + y_mean[2:4]
  true_box_wh = y_true[..., 2:4] * y_std[2:4] + y_mean[2:4]

  # Calcul des coordonnées minimales et maximales des boiptes englobantes réelles
  true_wh_half = true_box_wh / 2.
  true_mins    = true_box_xy - true_wh_half
  true_maxes   = true_box_xy + true_wh_half

  # Calcul des coordonnées minimales et maximales des boiptes englobantes prédites
  pred_wh_half = pred_box_wh / 2.
  pred_mins    = pred_box_xy - pred_wh_half
  pred_maxes   = pred_box_xy + pred_wh_half

  # Détermination de l'intersection des boîtes englobantes
  intersect_mins  = tf.maximum(pred_mins,  true_mins)
  intersect_maxes = tf.minimum(pred_maxes, true_maxes)
  intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
  intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]

  # Aire des boîtes englobantes prédites et réelles
  true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
  pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

  # Aire de l'union des boîtes prédites et réelles
  union_areas = pred_areas + true_areas - intersect_areas

  iou_scores  = tf.truediv(intersect_areas, union_areas)
  return iou_scores

def iou():
  def iou_metrics(y_true, y_pred):
    return compute_iou(y_true, y_pred)
  iou_metrics.__name__= "iou"
  return iou_metrics

# %% [markdown]
# Visualisation des données et labels

# %%
# Si seuls x et y sont indiqués, on tire au hasard un numéro d'image et on affiche le label y associé  à l'image
# Si un 2e y, nommé y_pred, est indiqué, alors les deux labels sont affichés côte à côte, afin de pouvoir les comparer
# Enfin on peut également indiquer l'id de l'image que l'on souhaite visualiser.
def print_data_localisation(x, y, y_pred=[], id=None, image_size=64):
  if id==None:
    # Tirage aléatoire d'une image dans la base
    num_img = np.random.randint(x.shape[0]-1)
  else:
    num_img = id

  img = x[num_img]
  lab = y[num_img]

  colors = ["blue", "yellow", "red", "orange", "coral", "gold", "ivory", "fuchsia", "purple", "cyan", "navy"] # Différentes couleurs pour les différentes classes
  classes = ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']

  if np.any(y_pred):
    plt.subplot(1, 2, 1)

  # Affichage de l'image
  plt.imshow(img)
  # Détermination de la classe
  class_id = np.argmax(lab[5:])

  # Détermination des coordonnées de la boîte englobante dans le repère image
  ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
  ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
  width = (lab[3]*y_std[3] + y_mean[3]) * image_size
  height = (lab[4]*y_std[4] + y_mean[4]) * image_size
  #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
  # Détermination des extrema de la boîte englobante
  p_x = [ax-width/2, ax+width/2]
  p_y = [ay-height/2, ay+height/2]
  # Affichage de la boîte englobante, dans la bonne couleur
  plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
  plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
  plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
  plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
  plt.title("Vérité Terrain : Image {} - {}".format(num_img, classes[class_id]))

  if np.any(y_pred):
    plt.subplot(1, 2, 2)
    # Affichage de l'image
    plt.imshow(img)
    lab = y_pred[num_img]
    # Détermination de la classe
    class_id = np.argmax(lab[5:])

    # Détermination des coordonnées de la boîte englobante dans le repère image
    ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
    ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
    width = (lab[3]*y_std[3] + y_mean[3]) * image_size
    height = (lab[4]*y_std[4] + y_mean[4]) * image_size
    #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
    # Détermination des extrema de la boîte englobante
    p_x = [ax-width/2, ax+width/2]
    p_y = [ay-height/2, ay+height/2]
    # Affichage de la boîte englobante, dans la bonne couleur
    plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
    plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
    plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
    plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
    plt.title("Prédiction : Image {} - {}".format(num_img, classes[class_id]))

  plt.show()

for i in range(10):#x.shape[0]):
    print_data_localisation(x_train, y_train, image_size=IMAGE_SIZE, id=i)

# %% [markdown]
# Fonction d'affichage des courbes d'apprentissage et de validation

# %%
def plot_training_analysis(history, metric='loss'):

  loss = history.history[metric]
  val_loss = history.history['val_' + metric]

  epochs = range(len(loss))

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training ' + metric)
  plt.plot(epochs, val_loss, 'g', label='Validation ' + metric)
  plt.title('Training and validation ' + metric)
  plt.legend()

  plt.show()

# %% [markdown]
# ## Travail à faire

# %% [markdown]
# <center> <img src="https://drive.google.com/thumbnail?id=1YzCZe4pgnjJDVGklAaCHZ7HhlPJsadg9&sz=w1000" width=500></center>
# <caption><center> Figure 3: Illustration de l'architecture du réseau à construire.  </center></caption>
#
# Complétez les codes qui vous sont fournis pour obtenir un algorithme de localisation.
# Vous pouvez utiliser n'importe quelle base convolutive de votre choix (vous pouvez vous inspirer du TP sur les CNN que nous avons fait l'an passé), en revanche vous devrez porter une attention particulière à la couche de sortie.
#
# Vous allez en fait produire 3 sorties différentes : une caractérisant la présence d'un objet, une autre fournissant les coordonnées de la boîte englobante, et enfin une dernière effectuant la classification.

# %%
def create_model_localisation(input_shape=(64, 64, 3)):

  input_layer = Input(shape=input_shape)

  conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = Conv2D(96, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
  pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

  conv5 = Conv2D(160, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
  pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)

  conv6 = Conv2D(192, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool5)
  pool6 = MaxPooling2D(pool_size=(2, 2))(conv6)
  # Cette couche vectorise le tenseur de sortie de votre base convolutive, et
  # constituera l'entrée des 3 couches de sortie ci-dessous
  flatten_layer = Flatten()(pool3)

  # amélioration avec cette couche dense
  prev_layer = Dense(6144, activation='relu')(flatten_layer)

  #### Couches de sortie A COMPLETER
  output_p = Dense(1, activation='sigmoid', name='p')(prev_layer)   # Sortie caractérisant la présence d'un objet
  output_coord = Dense(4, activation='linear', name='coord')(prev_layer) # Sortie caractérisant les coordonnées de boîte englobante
  output_class = Dense(num_classes, activation='softmax', name='classes')(prev_layer) # Sortie caractérisant les probabilités de classe

  output= [output_p, output_coord, output_class]
  model = Model(input_layer, output)

  print(model.summary())

  return model

# %% [markdown]
# <center> <img src="https://drive.google.com/thumbnail?id=1bnh8zU7Os-w-5TT8hV4xDoThKQc-Ywc2&sz=w1000" width=500></center>
# <caption><center> Figure 4: Illustration des fonctions de coût à utiliser pour l'entraînement. </center></caption>
#
# Pour entraîner votre réseau, vous allez donc devoir associer une fonction de coût à chacune des sorties du réseau. La fonction de coût totale sera la somme des trois fonctions de coût précédemment définies, pondérées par des poids définis dans la variable *loss_weights*.
#
# **Prenez le temps de tester différentes valeurs de *loss_weights* en fonction de l'évolution des métriques que vous observerez pendant l'entraînement.**
#
# Vous évaluerez vos résultats de manière qualitative (en affichant les boîtes englobantes prédites et réelles) mais aussi quantitatives grâce aux fonctions définies dans la section précédente. **N'hésitez pas à modifier un peu le paramètre iou_threshold positionné par défaut à 0.5** (une valeur de 0.4 vous permettra d'obtenir de meilleurs résultats !)

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)

# Ici mettre, dans l'ordre, les fonctions de coût associées à chacune des sorties
loss=[keras.losses.BinaryCrossentropy(), keras.losses.MeanSquaredError(), keras.losses.CategoricalCrossentropy()]
# On va associer une métrique à chaque sortie : l'accuracy pour les deux classifications,
# et l'IoU définie plus tôt pour la qualité des boîtes englobantes.
metrics=[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [20, 50, 1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
with tf.device('/GPU:0'):
    history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:]],
              epochs=50,
              batch_size=batch_size,
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 64, 64,    │        896 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 32, 32,    │          0 │ conv2d_18[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │     18,496 │ max_pooling2d_18… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 16, 16,    │          0 │ conv2d_19[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 16, 16,    │     55,392 │ max_pooling2d_19… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 8, 8, 96)  │          0 │ conv2d_20[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 6144)      │          0 │ max_pooling2d_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 6144)      │ 37,754,880 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p (Dense)           │ (None, 1)         │      6,145 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ coord (Dense)       │ (None, 4)         │     24,580 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classes (Dense)     │ (None, 11)        │     67,595 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 37,927,984 (144.68 MB)
#  Trainable params: 37,927,984 (144.68 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - classes_accuracy: 0.1793 - classes_loss: 2.3850 - coord_iou: 0.3409 - coord_loss: 6.4275 - loss: 324.4332 - p_accuracy: 0.9747 - p_loss: 0.0336 - val_classes_accuracy: 0.4000 - val_classes_loss: 2.0320 - val_coord_iou: 0.5215 - val_coord_loss: 0.5558 - val_loss: 29.9014 - val_p_accuracy: 1.0000 - val_p_loss: 5.9626e-04
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.4828 - classes_loss: 1.9172 - coord_iou: 0.5025 - coord_loss: 0.5428 - loss: 29.0699 - p_accuracy: 1.0000 - p_loss: 7.4536e-04 - val_classes_accuracy: 0.4190 - val_classes_loss: 1.6796 - val_coord_iou: 0.5327 - val_coord_loss: 0.4561 - val_loss: 24.9818 - val_p_accuracy: 1.0000 - val_p_loss: 4.1407e-04
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.4878 - classes_loss: 1.6388 - coord_iou: 0.5308 - coord_loss: 0.4183 - loss: 22.5641 - p_accuracy: 1.0000 - p_loss: 3.9968e-04 - val_classes_accuracy: 0.4905 - val_classes_loss: 1.5115 - val_coord_iou: 0.5442 - val_coord_loss: 0.4286 - val_loss: 23.4142 - val_p_accuracy: 1.0000 - val_p_loss: 1.9183e-04
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.5492 - classes_loss: 1.4536 - coord_iou: 0.5444 - coord_loss: 0.3641 - loss: 19.6637 - p_accuracy: 1.0000 - p_loss: 3.1145e-04 - val_classes_accuracy: 0.5286 - val_classes_loss: 1.3622 - val_coord_iou: 0.5227 - val_coord_loss: 0.3862 - val_loss: 21.3908 - val_p_accuracy: 1.0000 - val_p_loss: 1.8477e-04
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.5635 - classes_loss: 1.3075 - coord_iou: 0.5797 - coord_loss: 0.3014 - loss: 16.3813 - p_accuracy: 1.0000 - p_loss: 2.9061e-04 - val_classes_accuracy: 0.5048 - val_classes_loss: 1.2740 - val_coord_iou: 0.5428 - val_coord_loss: 0.3745 - val_loss: 20.2501 - val_p_accuracy: 1.0000 - val_p_loss: 1.6932e-04
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.5766 - classes_loss: 1.2360 - coord_iou: 0.5805 - coord_loss: 0.2653 - loss: 14.5057 - p_accuracy: 1.0000 - p_loss: 2.4270e-04 - val_classes_accuracy: 0.5190 - val_classes_loss: 1.2329 - val_coord_iou: 0.5722 - val_coord_loss: 0.3375 - val_loss: 18.5617 - val_p_accuracy: 1.0000 - val_p_loss: 6.8933e-05
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.5760 - classes_loss: 1.1847 - coord_iou: 0.6032 - coord_loss: 0.2474 - loss: 13.5592 - p_accuracy: 1.0000 - p_loss: 1.3346e-04 - val_classes_accuracy: 0.5333 - val_classes_loss: 1.1721 - val_coord_iou: 0.5709 - val_coord_loss: 0.3070 - val_loss: 17.0354 - val_p_accuracy: 1.0000 - val_p_loss: 1.8504e-04
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.6006 - classes_loss: 1.1297 - coord_iou: 0.6338 - coord_loss: 0.2020 - loss: 11.2310 - p_accuracy: 1.0000 - p_loss: 1.3914e-04 - val_classes_accuracy: 0.5190 - val_classes_loss: 1.1546 - val_coord_iou: 0.5722 - val_coord_loss: 0.3442 - val_loss: 18.7753 - val_p_accuracy: 1.0000 - val_p_loss: 7.0119e-05
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.6088 - classes_loss: 1.0870 - coord_iou: 0.6267 - coord_loss: 0.1875 - loss: 10.4647 - p_accuracy: 1.0000 - p_loss: 1.2986e-04 - val_classes_accuracy: 0.5524 - val_classes_loss: 1.0858 - val_coord_iou: 0.5720 - val_coord_loss: 0.3061 - val_loss: 16.9486 - val_p_accuracy: 1.0000 - val_p_loss: 8.0564e-05
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.6377 - classes_loss: 1.0221 - coord_iou: 0.6539 - coord_loss: 0.1592 - loss: 8.9851 - p_accuracy: 1.0000 - p_loss: 1.0040e-04 - val_classes_accuracy: 0.5619 - val_classes_loss: 1.0726 - val_coord_iou: 0.5900 - val_coord_loss: 0.2970 - val_loss: 16.3849 - val_p_accuracy: 1.0000 - val_p_loss: 4.5803e-05
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - classes_accuracy: 0.6392 - classes_loss: 0.9963 - coord_iou: 0.6751 - coord_loss: 0.1401 - loss: 8.0018 - p_accuracy: 1.0000 - p_loss: 7.0584e-05 - val_classes_accuracy: 0.5667 - val_classes_loss: 1.0309 - val_coord_iou: 0.5630 - val_coord_loss: 0.2835 - val_loss: 15.7811 - val_p_accuracy: 1.0000 - val_p_loss: 5.2474e-05
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - classes_accuracy: 0.6560 - classes_loss: 0.9444 - coord_iou: 0.6850 - coord_loss: 0.1169 - loss: 6.7893 - p_accuracy: 1.0000 - p_loss: 5.8277e-05 - val_classes_accuracy: 0.5810 - val_classes_loss: 1.0357 - val_coord_iou: 0.5785 - val_coord_loss: 0.3072 - val_loss: 16.9157 - val_p_accuracy: 1.0000 - val_p_loss: 5.2930e-05
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.6475 - classes_loss: 0.9575 - coord_iou: 0.6564 - coord_loss: 0.1315 - loss: 7.5359 - p_accuracy: 1.0000 - p_loss: 7.7763e-05 - val_classes_accuracy: 0.5714 - val_classes_loss: 1.0008 - val_coord_iou: 0.6053 - val_coord_loss: 0.2767 - val_loss: 15.2494 - val_p_accuracy: 1.0000 - val_p_loss: 6.4304e-05
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.6763 - classes_loss: 0.9126 - coord_iou: 0.7114 - coord_loss: 0.0991 - loss: 5.8669 - p_accuracy: 1.0000 - p_loss: 6.2552e-05 - val_classes_accuracy: 0.5857 - val_classes_loss: 0.9589 - val_coord_iou: 0.5955 - val_coord_loss: 0.2799 - val_loss: 15.3306 - val_p_accuracy: 1.0000 - val_p_loss: 1.9305e-05
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.6822 - classes_loss: 0.8790 - coord_iou: 0.7114 - coord_loss: 0.0950 - loss: 5.6293 - p_accuracy: 1.0000 - p_loss: 4.6887e-05 - val_classes_accuracy: 0.6143 - val_classes_loss: 0.9562 - val_coord_iou: 0.6084 - val_coord_loss: 0.2827 - val_loss: 15.3202 - val_p_accuracy: 1.0000 - val_p_loss: 3.1531e-05
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7035 - classes_loss: 0.8432 - coord_iou: 0.7432 - coord_loss: 0.0775 - loss: 4.7178 - p_accuracy: 1.0000 - p_loss: 4.7204e-05 - val_classes_accuracy: 0.6143 - val_classes_loss: 0.9533 - val_coord_iou: 0.6059 - val_coord_loss: 0.2815 - val_loss: 15.2729 - val_p_accuracy: 1.0000 - val_p_loss: 4.1136e-05
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7243 - classes_loss: 0.7649 - coord_iou: 0.7404 - coord_loss: 0.0735 - loss: 4.4402 - p_accuracy: 1.0000 - p_loss: 3.6367e-05 - val_classes_accuracy: 0.6190 - val_classes_loss: 0.9098 - val_coord_iou: 0.6077 - val_coord_loss: 0.2606 - val_loss: 14.2594 - val_p_accuracy: 1.0000 - val_p_loss: 1.9510e-05
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7073 - classes_loss: 0.8072 - coord_iou: 0.7413 - coord_loss: 0.0653 - loss: 4.0752 - p_accuracy: 1.0000 - p_loss: 3.2657e-05 - val_classes_accuracy: 0.6238 - val_classes_loss: 0.9330 - val_coord_iou: 0.6027 - val_coord_loss: 0.2895 - val_loss: 15.8234 - val_p_accuracy: 1.0000 - val_p_loss: 3.4107e-05
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7303 - classes_loss: 0.7633 - coord_iou: 0.7520 - coord_loss: 0.0654 - loss: 4.0361 - p_accuracy: 1.0000 - p_loss: 3.4505e-05 - val_classes_accuracy: 0.6286 - val_classes_loss: 0.8928 - val_coord_iou: 0.6165 - val_coord_loss: 0.2707 - val_loss: 14.8350 - val_p_accuracy: 1.0000 - val_p_loss: 1.8684e-05
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7279 - classes_loss: 0.7604 - coord_iou: 0.7774 - coord_loss: 0.0521 - loss: 3.3663 - p_accuracy: 1.0000 - p_loss: 2.7470e-05 - val_classes_accuracy: 0.6524 - val_classes_loss: 0.8762 - val_coord_iou: 0.6133 - val_coord_loss: 0.2713 - val_loss: 14.8125 - val_p_accuracy: 1.0000 - val_p_loss: 2.1817e-05
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7355 - classes_loss: 0.7174 - coord_iou: 0.7764 - coord_loss: 0.0519 - loss: 3.3151 - p_accuracy: 1.0000 - p_loss: 3.1021e-05 - val_classes_accuracy: 0.6381 - val_classes_loss: 0.8721 - val_coord_iou: 0.6013 - val_coord_loss: 0.2713 - val_loss: 14.5971 - val_p_accuracy: 1.0000 - val_p_loss: 3.3567e-05
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7673 - classes_loss: 0.6554 - coord_iou: 0.7712 - coord_loss: 0.0457 - loss: 2.9388 - p_accuracy: 1.0000 - p_loss: 3.1564e-05 - val_classes_accuracy: 0.6667 - val_classes_loss: 0.8703 - val_coord_iou: 0.6261 - val_coord_loss: 0.2669 - val_loss: 14.6423 - val_p_accuracy: 1.0000 - val_p_loss: 2.3263e-05
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7476 - classes_loss: 0.6710 - coord_iou: 0.7870 - coord_loss: 0.0428 - loss: 2.8110 - p_accuracy: 1.0000 - p_loss: 3.0308e-05 - val_classes_accuracy: 0.6571 - val_classes_loss: 0.8414 - val_coord_iou: 0.6024 - val_coord_loss: 0.2648 - val_loss: 14.3206 - val_p_accuracy: 1.0000 - val_p_loss: 1.4127e-05
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8002 - classes_loss: 0.6141 - coord_iou: 0.7773 - coord_loss: 0.0381 - loss: 2.5186 - p_accuracy: 1.0000 - p_loss: 2.4595e-05 - val_classes_accuracy: 0.6381 - val_classes_loss: 0.8602 - val_coord_iou: 0.6092 - val_coord_loss: 0.2725 - val_loss: 14.6877 - val_p_accuracy: 1.0000 - val_p_loss: 1.2000e-05
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.7954 - classes_loss: 0.6034 - coord_iou: 0.7958 - coord_loss: 0.0329 - loss: 2.2484 - p_accuracy: 1.0000 - p_loss: 1.9876e-05 - val_classes_accuracy: 0.6762 - val_classes_loss: 0.8402 - val_coord_iou: 0.6159 - val_coord_loss: 0.2701 - val_loss: 14.6946 - val_p_accuracy: 1.0000 - val_p_loss: 1.4078e-05
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8206 - classes_loss: 0.5744 - coord_iou: 0.8017 - coord_loss: 0.0344 - loss: 2.2964 - p_accuracy: 1.0000 - p_loss: 2.0785e-05 - val_classes_accuracy: 0.6524 - val_classes_loss: 0.8048 - val_coord_iou: 0.6251 - val_coord_loss: 0.2540 - val_loss: 13.8952 - val_p_accuracy: 1.0000 - val_p_loss: 1.3350e-05
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - classes_accuracy: 0.8114 - classes_loss: 0.5628 - coord_iou: 0.8158 - coord_loss: 0.0305 - loss: 2.0906 - p_accuracy: 1.0000 - p_loss: 1.8447e-05 - val_classes_accuracy: 0.6667 - val_classes_loss: 0.8335 - val_coord_iou: 0.6065 - val_coord_loss: 0.2717 - val_loss: 14.7714 - val_p_accuracy: 1.0000 - val_p_loss: 1.0736e-05
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8223 - classes_loss: 0.5476 - coord_iou: 0.8084 - coord_loss: 0.0320 - loss: 2.1473 - p_accuracy: 1.0000 - p_loss: 1.7988e-05 - val_classes_accuracy: 0.7000 - val_classes_loss: 0.8151 - val_coord_iou: 0.6035 - val_coord_loss: 0.2717 - val_loss: 14.6142 - val_p_accuracy: 1.0000 - val_p_loss: 1.4933e-05
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8517 - classes_loss: 0.5138 - coord_iou: 0.8116 - coord_loss: 0.0288 - loss: 1.9564 - p_accuracy: 1.0000 - p_loss: 1.9142e-05 - val_classes_accuracy: 0.6952 - val_classes_loss: 0.8020 - val_coord_iou: 0.6281 - val_coord_loss: 0.2545 - val_loss: 13.8573 - val_p_accuracy: 1.0000 - val_p_loss: 1.1599e-05
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - classes_accuracy: 0.8388 - classes_loss: 0.4863 - coord_iou: 0.8416 - coord_loss: 0.0218 - loss: 1.5778 - p_accuracy: 1.0000 - p_loss: 1.4978e-05 - val_classes_accuracy: 0.7048 - val_classes_loss: 0.8121 - val_coord_iou: 0.6049 - val_coord_loss: 0.2640 - val_loss: 14.3066 - val_p_accuracy: 1.0000 - val_p_loss: 1.0679e-05
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8567 - classes_loss: 0.4748 - coord_iou: 0.8171 - coord_loss: 0.0259 - loss: 1.7701 - p_accuracy: 1.0000 - p_loss: 1.4332e-05 - val_classes_accuracy: 0.7095 - val_classes_loss: 0.8206 - val_coord_iou: 0.6201 - val_coord_loss: 0.2618 - val_loss: 14.0496 - val_p_accuracy: 1.0000 - val_p_loss: 1.1753e-05
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8779 - classes_loss: 0.4404 - coord_iou: 0.8181 - coord_loss: 0.0276 - loss: 1.8192 - p_accuracy: 1.0000 - p_loss: 1.4472e-05 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.8020 - val_coord_iou: 0.6179 - val_coord_loss: 0.2736 - val_loss: 14.7431 - val_p_accuracy: 1.0000 - val_p_loss: 1.1972e-05
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8686 - classes_loss: 0.4383 - coord_iou: 0.8291 - coord_loss: 0.0270 - loss: 1.7895 - p_accuracy: 1.0000 - p_loss: 1.4617e-05 - val_classes_accuracy: 0.7095 - val_classes_loss: 0.8035 - val_coord_iou: 0.6211 - val_coord_loss: 0.2561 - val_loss: 13.8796 - val_p_accuracy: 1.0000 - val_p_loss: 8.9435e-06
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8842 - classes_loss: 0.4107 - coord_iou: 0.8400 - coord_loss: 0.0210 - loss: 1.4631 - p_accuracy: 1.0000 - p_loss: 1.2555e-05 - val_classes_accuracy: 0.7238 - val_classes_loss: 0.7857 - val_coord_iou: 0.6203 - val_coord_loss: 0.2528 - val_loss: 13.7137 - val_p_accuracy: 1.0000 - val_p_loss: 7.8829e-06
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8970 - classes_loss: 0.3826 - coord_iou: 0.8450 - coord_loss: 0.0187 - loss: 1.3174 - p_accuracy: 1.0000 - p_loss: 1.1808e-05 - val_classes_accuracy: 0.7000 - val_classes_loss: 0.8296 - val_coord_iou: 0.6077 - val_coord_loss: 0.2633 - val_loss: 14.0698 - val_p_accuracy: 1.0000 - val_p_loss: 7.1105e-06
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8977 - classes_loss: 0.3642 - coord_iou: 0.8541 - coord_loss: 0.0175 - loss: 1.2416 - p_accuracy: 1.0000 - p_loss: 9.0625e-06 - val_classes_accuracy: 0.6952 - val_classes_loss: 0.7926 - val_coord_iou: 0.6124 - val_coord_loss: 0.2722 - val_loss: 14.6989 - val_p_accuracy: 1.0000 - val_p_loss: 7.6429e-06
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.8968 - classes_loss: 0.3648 - coord_iou: 0.8464 - coord_loss: 0.0176 - loss: 1.2455 - p_accuracy: 1.0000 - p_loss: 9.7534e-06 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.7833 - val_coord_iou: 0.6353 - val_coord_loss: 0.2622 - val_loss: 14.0889 - val_p_accuracy: 1.0000 - val_p_loss: 8.8423e-06
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9062 - classes_loss: 0.3447 - coord_iou: 0.8391 - coord_loss: 0.0204 - loss: 1.3649 - p_accuracy: 1.0000 - p_loss: 9.9399e-06 - val_classes_accuracy: 0.7238 - val_classes_loss: 0.7816 - val_coord_iou: 0.6262 - val_coord_loss: 0.2522 - val_loss: 13.5439 - val_p_accuracy: 1.0000 - val_p_loss: 7.9782e-06
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9322 - classes_loss: 0.3212 - coord_iou: 0.8330 - coord_loss: 0.0203 - loss: 1.3374 - p_accuracy: 1.0000 - p_loss: 1.1255e-05 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.7478 - val_coord_iou: 0.6204 - val_coord_loss: 0.2640 - val_loss: 14.0942 - val_p_accuracy: 1.0000 - val_p_loss: 9.1590e-06
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - classes_accuracy: 0.9396 - classes_loss: 0.2984 - coord_iou: 0.8327 - coord_loss: 0.0201 - loss: 1.3049 - p_accuracy: 1.0000 - p_loss: 9.2794e-06 - val_classes_accuracy: 0.7048 - val_classes_loss: 0.7467 - val_coord_iou: 0.6294 - val_coord_loss: 0.2556 - val_loss: 13.6979 - val_p_accuracy: 1.0000 - val_p_loss: 6.4324e-06
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9332 - classes_loss: 0.2766 - coord_iou: 0.8423 - coord_loss: 0.0171 - loss: 1.1294 - p_accuracy: 1.0000 - p_loss: 8.4126e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.7693 - val_coord_iou: 0.6268 - val_coord_loss: 0.2657 - val_loss: 14.1897 - val_p_accuracy: 1.0000 - val_p_loss: 8.0446e-06
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9320 - classes_loss: 0.2929 - coord_iou: 0.8349 - coord_loss: 0.0202 - loss: 1.3042 - p_accuracy: 1.0000 - p_loss: 9.6809e-06 - val_classes_accuracy: 0.7238 - val_classes_loss: 0.7705 - val_coord_iou: 0.6198 - val_coord_loss: 0.2683 - val_loss: 14.2517 - val_p_accuracy: 1.0000 - val_p_loss: 5.8331e-06
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9427 - classes_loss: 0.2571 - coord_iou: 0.8395 - coord_loss: 0.0208 - loss: 1.2972 - p_accuracy: 1.0000 - p_loss: 1.0154e-05 - val_classes_accuracy: 0.7238 - val_classes_loss: 0.7514 - val_coord_iou: 0.6263 - val_coord_loss: 0.2556 - val_loss: 13.7647 - val_p_accuracy: 1.0000 - val_p_loss: 9.0398e-06
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9475 - classes_loss: 0.2469 - coord_iou: 0.8556 - coord_loss: 0.0174 - loss: 1.1195 - p_accuracy: 1.0000 - p_loss: 7.3526e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.7839 - val_coord_iou: 0.6295 - val_coord_loss: 0.2504 - val_loss: 13.5674 - val_p_accuracy: 1.0000 - val_p_loss: 8.2092e-06
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9461 - classes_loss: 0.2331 - coord_iou: 0.8529 - coord_loss: 0.0173 - loss: 1.1005 - p_accuracy: 1.0000 - p_loss: 6.9272e-06 - val_classes_accuracy: 0.7429 - val_classes_loss: 0.7396 - val_coord_iou: 0.6324 - val_coord_loss: 0.2536 - val_loss: 13.5864 - val_p_accuracy: 1.0000 - val_p_loss: 6.7828e-06
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9514 - classes_loss: 0.2157 - coord_iou: 0.8458 - coord_loss: 0.0173 - loss: 1.0830 - p_accuracy: 1.0000 - p_loss: 6.4980e-06 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.7715 - val_coord_iou: 0.6121 - val_coord_loss: 0.2580 - val_loss: 13.7376 - val_p_accuracy: 1.0000 - val_p_loss: 3.6772e-06
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9606 - classes_loss: 0.1970 - coord_iou: 0.8594 - coord_loss: 0.0144 - loss: 0.9184 - p_accuracy: 1.0000 - p_loss: 6.1153e-06 - val_classes_accuracy: 0.7286 - val_classes_loss: 0.7959 - val_coord_iou: 0.6331 - val_coord_loss: 0.2573 - val_loss: 13.7927 - val_p_accuracy: 1.0000 - val_p_loss: 4.7055e-06
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9620 - classes_loss: 0.1920 - coord_iou: 0.8624 - coord_loss: 0.0164 - loss: 1.0117 - p_accuracy: 1.0000 - p_loss: 6.6206e-06 - val_classes_accuracy: 0.7333 - val_classes_loss: 0.7582 - val_coord_iou: 0.6265 - val_coord_loss: 0.2537 - val_loss: 13.6205 - val_p_accuracy: 1.0000 - val_p_loss: 5.3262e-06
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9713 - classes_loss: 0.1815 - coord_iou: 0.8583 - coord_loss: 0.0161 - loss: 0.9848 - p_accuracy: 1.0000 - p_loss: 6.1326e-06 - val_classes_accuracy: 0.7381 - val_classes_loss: 0.7703 - val_coord_iou: 0.6211 - val_coord_loss: 0.2580 - val_loss: 13.8619 - val_p_accuracy: 1.0000 - val_p_loss: 3.2694e-06
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - classes_accuracy: 0.9639 - classes_loss: 0.1803 - coord_iou: 0.8367 - coord_loss: 0.0168 - loss: 1.0207 - p_accuracy: 1.0000 - p_loss: 5.0723e-06 - val_classes_accuracy: 0.7381 - val_classes_loss: 0.7745 - val_coord_iou: 0.6289 - val_coord_loss: 0.2506 - val_loss: 13.5785 - val_p_accuracy: 1.0000 - val_p_loss: 2.9900e-06

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_iou')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x71b32e0256c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# /tmp/ipykernel_167811/1470267387.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i, 0] = y_pred_presence[i]

# %%
class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# La précision globale est de 64.4%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.40    |  0.27  |   0.32   |
# ------------------------------------------
# | VEREUR |   0.71    |  0.77  |   0.74   |
# ------------------------------------------
# | ECUROU |   0.87    |  0.91  |   0.89   |
# ------------------------------------------
# | PIEBAV |   0.87    |  0.91  |   0.89   |
# ------------------------------------------
# | SITTOR |   0.55    |  0.27  |   0.36   |
# ------------------------------------------
# | PINARB |   0.71    |  0.77  |   0.74   |
# ------------------------------------------
# | MESNOI |   0.42    |  0.79  |   0.55   |
# ------------------------------------------
# | MESNON |   0.39    |  0.32  |   0.35   |
# ------------------------------------------
# | MESBLE |   0.42    |  0.45  |   0.43   |
# ------------------------------------------
# | ROUGOR |   0.82    |  0.86  |   0.84   |
# ------------------------------------------
# | ACCMOU |   0.78    |  0.82  |   0.80   |
# ------------------------------------------

# %% [markdown]
# En pratique, il est délicat de trouver une bonne combinaison des fonctions de perte tel que vous l'avez fait sur les cellules précédentes. L'entropie croisée et l'erreur quadratique moyenne donnent des valeurs trop différentes pour être combinables efficacement.
#
# Une variante, peut-être plus simple à faire fonctionner, est d'utiliser uniquement l'erreur quadratique moyenne comme perte pour toutes les sorties. C'est cette variante qui est implémentée dans l'algorithme YOLO, dont nous implémenterons une version simplifiée dans la suite du TP.
# Testez cette solution ci-dessous. Comme sur l'exercice précédent, n'hésitez pas à faire varier le poids des différents éléments de la fonction de coût.

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)

loss = [keras.losses.MeanSquaredError(), keras.losses.MeanSquaredError(), keras.losses.MeanSquaredError()]
metrics =[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1,1,1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )

with tf.device('/GPU:0'):
    history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:]],
              epochs=50,
              batch_size=batch_size,
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_iou')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# /tmp/ipykernel_23728/713093020.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i, 0] = y_pred_presence[i]
# La précision globale est de 62.2%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.38    |  0.23  |   0.29   |
# ------------------------------------------
# | VEREUR |   0.64    |  0.73  |   0.68   |
# ------------------------------------------
# | ECUROU |   0.87    |  0.91  |   0.89   |
# ------------------------------------------
# | PIEBAV |   0.95    |  0.95  |   0.95   |
# ------------------------------------------
# | SITTOR |   0.50    |  0.45  |   0.48   |
# ------------------------------------------
# | PINARB |   0.71    |  0.77  |   0.74   |
# ------------------------------------------
# | MESNOI |   0.43    |  0.71  |   0.54   |
# ------------------------------------------
# | MESNON |   0.35    |  0.27  |   0.31   |
# ------------------------------------------
# | MESBLE |   0.33    |  0.32  |   0.33   |
# ------------------------------------------
# | ROUGOR |   0.76    |  0.76  |   0.76   |
# ------------------------------------------
# | ACCMOU |   0.71    |  0.77  |   0.74   |
# ------------------------------------------

# %% [markdown]
# Compte-tenu de la taille réduite de la base de données, les résultats ne sont pas mal du tout ! On observe quelques confusions entre certaines classes mais les prédictions sont souvent intéressantes.
#
# **Fin de la séance 1**
#
# ---

# %% [markdown]
# **Pour aller plus loin :**
#
# Il devrait cependant subsister un fort surapprentissage à ce stade. Comme nous l'avons vu en première année, vous avez plusieurs possibilités qui s'offrent à vous pour le corriger :
#
# *   Augmentation de la base de données. Vous pouvez pour cela vous appuyer sur le code fourni cu-dessous, avec une classe *Sequence* et l'utilisation de la librairie *Albumentation*.
# *   Utilisation de *transfer learning* : partant d'un réseau entraîné sur ImageNet (qui contient de nombreuses classes d'animaux), vous bénéficieriez de filtres très généraux qui aiderait à limiter le surapprentissage.

# %% [markdown]
# ## Quelques bouts de code pour vous aider à aller un peu plus loin
#
# L'augmentation seule aide déjà un peu, mais le transfer learning accompagné d'augmentation de données donne les meilleurs résultats, avec presque 80% de bonnes détections !

# %% [markdown]
# ### Augmentation de données

# %% [markdown]
# Le bloc de code suivant permet de définir des transformations colorimétriques à appliquer à notre base de données, de manière à augmenter artificiellement le nombre d'images de celles-ci :

# %%
from albumentations import (Compose, RandomBrightnessContrast, RandomGamma, ShiftScaleRotate, RandomSizedBBoxSafeCrop)
import albumentations as A

AUGMENTATIONS_TRAIN = Compose([
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), p=0.5)
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))
# Out:
# /home/cycy/Documents/ENSEEIHT/2A/Apprentissage/TP/.venv/lib/python3.12/site-packages/albumentations/core/composition.py:250: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()

# %% [markdown]
# En première année, nous avons implémenté l'augmentation de données à l'aide d'un objet ImageDataGenerator. La limite de cette méthode est qu'elle ne peut s'appliquer que dans des cas où l'augmentation de données ne modifie pas le label associé à l'image. C'était le cas dans le TP de l'an passé sur les chiens et les chats : appliquer une rotation ou une translation à une image de chien (ou de chat) ne changeait rien au fait que l'image montrait un chien (ou un chat).
#
# Ici, il peut arriver que certaines transformations altèrent le label : une rotation appliquée à un objet en changera nécessairement les coordonnées de boîte englobante.
# Pour gérer cette difficulté, on va implémenter nous même le chargement des données, à l'aide d'un objet ```Sequence``` (défini ci-dessous).
#
# La méthode ```__get_item()__``` récupère les données et labels du prochain batch à fournir au modèle pour la descente de gradient. On peut ainsi, à la volée, appliquer l'augmentation de données sur les images et impacter la modification sur les labels associés (fonction ```apply_augmentation```).

# %%
from tensorflow.keras.utils import Sequence

class MangeoireSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_set, y_set, batch_size,augmentations):
        self.x, self.y = x_set, y_set
        self.classes = ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(x_set.shape[0])
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    # Il y a des problèmes d'arrondi dans les conversions de boîtes englobantes
    # internes à la librairie Albumentations
    # Pour les contourner, si les boîtes sont trop proches des bords, on les érode un peu
    def erode_bounding_box(self, box):
        epsilon = 0.01

        xmin = max(box[0] - box[2]/2, epsilon)
        ymin = max(box[1] - box[3]/2, epsilon)
        xmax = min(box[0] + box[2]/2, 1-epsilon)
        ymax = min(box[1] + box[3]/2, 1-epsilon)

        cx = xmin + (xmax - xmin)/2
        cy = ymin + (ymax - ymin)/2
        width = xmax - xmin
        height = ymax - ymin

        return np.array([cx, cy, width, height])

    # Application de l'augmentation de données à chaque image du batch et aux
    # boîtes englobantes associées
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
        batch_y = by

        # Pour chaque image du batch
        for i in range(len(bx)):
            bboxes = []
            box = by[i,1:5]
            # Dénormalisation des coordonnées de boites englobantes
            box[0] = (box[0]*y_std[1] + y_mean[1])
            box[1] = (box[1]*y_std[2] + y_mean[2])
            box[2] = (box[2]*y_std[3] + y_mean[3])
            box[3] = (box[3]*y_std[4] + y_mean[4])
            box = self.erode_bounding_box(box)
            bboxes.append(box)

            class_labels = []
            class_id = np.argmax(by[i, 5:])
            class_labels.append(self.classes[class_id])

            img = bx[i]

            # Application de l'augmentation à l'image et aux masques
            transformed = self.augment(image=img.astype('float32'), bboxes=bboxes, class_labels=class_labels)
            batch_x[i] = transformed['image']
            batch_y_transformed = transformed['bboxes']

            # Renormalisation des coordonnées de boîte englobante transformée
            batch_y[i, 1] = (batch_y_transformed[0][0] - y_mean[1])/y_std[1]
            batch_y[i, 2] = (batch_y_transformed[0][1] - y_mean[2])/y_std[2]
            batch_y[i, 3] = (batch_y_transformed[0][2] - y_mean[3])/y_std[3]
            batch_y[i, 4] = (batch_y_transformed[0][3] - y_mean[4])/y_std[4]

        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    def __getitem__(self, idx):
        batch_x = self.x[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)

        batch_y = np.array(batch_y)
        return np.array(batch_x), (batch_y[:,0], batch_y[:,1:5].astype('float32'), batch_y[:,5:])

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %% [markdown]
# On peut ensuite instancier notre objet ```Sequence``` et afficher un exemple d'image augmentée avec le label associé.

# %%
# Instanciation d'une Sequence
train_gen = MangeoireSequence(x_train, y_train, 16, augmentations=AUGMENTATIONS_TRAIN)

# Pour tester la séquence, nous sélectionnons les éléments du premier batch et les affichons
batch_x, batch_y = train_gen.__getitem__(0)

y_batch = np.zeros((batch_y[0].shape[0],1+4+num_classes))

for i in range(batch_y[0].shape[0]):
  y_batch[i, 0] = batch_y[0][i]
  y_batch[i, 1:5] = batch_y[1][i]
  y_batch[i, 5:] = batch_y[2][i]

print_data_localisation(batch_x, y_batch, image_size=IMAGE_SIZE)

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)

loss = [keras.losses.MeanSquaredError(), keras.losses.MeanSquaredError(), keras.losses.MeanSquaredError()]
metrics =[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1,1,1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )

with tf.device('/GPU:0'):
    history = model.fit(train_gen,
              epochs=50,
              batch_size=batch_size,
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │        896 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     18,496 │ max_pooling2d_12… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 16, 16,    │          0 │ conv2d_13[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │     55,392 │ max_pooling2d_13… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 8, 8, 96)  │          0 │ conv2d_14[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 6144)      │          0 │ max_pooling2d_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 6144)      │ 37,754,880 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p (Dense)           │ (None, 1)         │      6,145 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ coord (Dense)       │ (None, 4)         │     24,580 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classes (Dense)     │ (None, 11)        │     67,595 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 37,927,984 (144.68 MB)
#  Trainable params: 37,927,984 (144.68 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - classes_accuracy: 0.1338 - classes_loss: 0.0822 - coord_iou: 0.3103 - coord_loss: 6.0866 - loss: 6.1761 - p_accuracy: 1.0000 - p_loss: 0.0059 - val_classes_accuracy: 0.3762 - val_classes_loss: 0.0747 - val_coord_iou: 0.4962 - val_coord_loss: 0.5341 - val_loss: 0.6209 - val_p_accuracy: 1.0000 - val_p_loss: 1.0505e-04
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.3799 - classes_loss: 0.0723 - coord_iou: 0.4944 - coord_loss: 0.5181 - loss: 0.5906 - p_accuracy: 1.0000 - p_loss: 2.4852e-04 - val_classes_accuracy: 0.4524 - val_classes_loss: 0.0628 - val_coord_iou: 0.5449 - val_coord_loss: 0.4375 - val_loss: 0.5127 - val_p_accuracy: 1.0000 - val_p_loss: 5.4979e-05
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.4780 - classes_loss: 0.0618 - coord_iou: 0.5195 - coord_loss: 0.4340 - loss: 0.4964 - p_accuracy: 1.0000 - p_loss: 1.1608e-04 - val_classes_accuracy: 0.4905 - val_classes_loss: 0.0581 - val_coord_iou: 0.5300 - val_coord_loss: 0.4298 - val_loss: 0.4968 - val_p_accuracy: 1.0000 - val_p_loss: 4.4786e-05
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.5320 - classes_loss: 0.0559 - coord_iou: 0.5414 - coord_loss: 0.3742 - loss: 0.4303 - p_accuracy: 1.0000 - p_loss: 1.5082e-04 - val_classes_accuracy: 0.5238 - val_classes_loss: 0.0552 - val_coord_iou: 0.5526 - val_coord_loss: 0.3861 - val_loss: 0.4485 - val_p_accuracy: 1.0000 - val_p_loss: 7.4135e-05
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.5697 - classes_loss: 0.0526 - coord_iou: 0.5725 - coord_loss: 0.3378 - loss: 0.3905 - p_accuracy: 1.0000 - p_loss: 8.4087e-05 - val_classes_accuracy: 0.5381 - val_classes_loss: 0.0527 - val_coord_iou: 0.5489 - val_coord_loss: 0.3389 - val_loss: 0.4032 - val_p_accuracy: 1.0000 - val_p_loss: 2.6955e-05
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.5901 - classes_loss: 0.0501 - coord_iou: 0.5789 - coord_loss: 0.2780 - loss: 0.3283 - p_accuracy: 1.0000 - p_loss: 4.9471e-05 - val_classes_accuracy: 0.5571 - val_classes_loss: 0.0513 - val_coord_iou: 0.5681 - val_coord_loss: 0.3380 - val_loss: 0.4015 - val_p_accuracy: 1.0000 - val_p_loss: 2.2731e-05
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.6133 - classes_loss: 0.0476 - coord_iou: 0.5975 - coord_loss: 0.2526 - loss: 0.3003 - p_accuracy: 1.0000 - p_loss: 4.6826e-05 - val_classes_accuracy: 0.5667 - val_classes_loss: 0.0503 - val_coord_iou: 0.5481 - val_coord_loss: 0.3233 - val_loss: 0.3873 - val_p_accuracy: 1.0000 - val_p_loss: 1.4955e-05
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.6055 - classes_loss: 0.0462 - coord_iou: 0.6104 - coord_loss: 0.2328 - loss: 0.2790 - p_accuracy: 1.0000 - p_loss: 3.1092e-05 - val_classes_accuracy: 0.5619 - val_classes_loss: 0.0488 - val_coord_iou: 0.5765 - val_coord_loss: 0.3120 - val_loss: 0.3704 - val_p_accuracy: 1.0000 - val_p_loss: 5.6381e-06
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.6473 - classes_loss: 0.0440 - coord_iou: 0.6300 - coord_loss: 0.2072 - loss: 0.2513 - p_accuracy: 1.0000 - p_loss: 2.9163e-05 - val_classes_accuracy: 0.5524 - val_classes_loss: 0.0478 - val_coord_iou: 0.5411 - val_coord_loss: 0.3245 - val_loss: 0.3857 - val_p_accuracy: 1.0000 - val_p_loss: 9.1420e-06
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.6577 - classes_loss: 0.0420 - coord_iou: 0.6423 - coord_loss: 0.1785 - loss: 0.2205 - p_accuracy: 1.0000 - p_loss: 2.5083e-05 - val_classes_accuracy: 0.5952 - val_classes_loss: 0.0462 - val_coord_iou: 0.5676 - val_coord_loss: 0.3099 - val_loss: 0.3646 - val_p_accuracy: 1.0000 - val_p_loss: 8.6969e-06
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.6647 - classes_loss: 0.0416 - coord_iou: 0.6553 - coord_loss: 0.1542 - loss: 0.1960 - p_accuracy: 1.0000 - p_loss: 2.0308e-05 - val_classes_accuracy: 0.5905 - val_classes_loss: 0.0455 - val_coord_iou: 0.5984 - val_coord_loss: 0.2772 - val_loss: 0.3310 - val_p_accuracy: 1.0000 - val_p_loss: 9.3795e-06
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.6822 - classes_loss: 0.0404 - coord_iou: 0.6675 - coord_loss: 0.1342 - loss: 0.1745 - p_accuracy: 1.0000 - p_loss: 1.9955e-05 - val_classes_accuracy: 0.6000 - val_classes_loss: 0.0444 - val_coord_iou: 0.5976 - val_coord_loss: 0.2739 - val_loss: 0.3281 - val_p_accuracy: 1.0000 - val_p_loss: 4.9452e-06
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.6900 - classes_loss: 0.0385 - coord_iou: 0.6867 - coord_loss: 0.1207 - loss: 0.1592 - p_accuracy: 1.0000 - p_loss: 1.2089e-05 - val_classes_accuracy: 0.6333 - val_classes_loss: 0.0422 - val_coord_iou: 0.6079 - val_coord_loss: 0.2855 - val_loss: 0.3395 - val_p_accuracy: 1.0000 - val_p_loss: 2.0873e-06
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.6968 - classes_loss: 0.0376 - coord_iou: 0.6796 - coord_loss: 0.1229 - loss: 0.1605 - p_accuracy: 1.0000 - p_loss: 1.2195e-05 - val_classes_accuracy: 0.6238 - val_classes_loss: 0.0442 - val_coord_iou: 0.5999 - val_coord_loss: 0.2796 - val_loss: 0.3336 - val_p_accuracy: 1.0000 - val_p_loss: 2.5363e-06
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.7172 - classes_loss: 0.0359 - coord_iou: 0.7031 - coord_loss: 0.1049 - loss: 0.1407 - p_accuracy: 1.0000 - p_loss: 1.2984e-05 - val_classes_accuracy: 0.6524 - val_classes_loss: 0.0422 - val_coord_iou: 0.5578 - val_coord_loss: 0.2824 - val_loss: 0.3341 - val_p_accuracy: 1.0000 - val_p_loss: 4.8779e-06
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.7444 - classes_loss: 0.0333 - coord_iou: 0.6987 - coord_loss: 0.0991 - loss: 0.1324 - p_accuracy: 1.0000 - p_loss: 8.6782e-06 - val_classes_accuracy: 0.6476 - val_classes_loss: 0.0414 - val_coord_iou: 0.5883 - val_coord_loss: 0.2822 - val_loss: 0.3324 - val_p_accuracy: 1.0000 - val_p_loss: 3.1673e-06
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.7166 - classes_loss: 0.0348 - coord_iou: 0.7242 - coord_loss: 0.0888 - loss: 0.1236 - p_accuracy: 1.0000 - p_loss: 9.5739e-06 - val_classes_accuracy: 0.6619 - val_classes_loss: 0.0412 - val_coord_iou: 0.5988 - val_coord_loss: 0.2911 - val_loss: 0.3432 - val_p_accuracy: 1.0000 - val_p_loss: 1.9076e-06
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.7559 - classes_loss: 0.0323 - coord_iou: 0.7227 - coord_loss: 0.0844 - loss: 0.1167 - p_accuracy: 1.0000 - p_loss: 8.2923e-06 - val_classes_accuracy: 0.6619 - val_classes_loss: 0.0407 - val_coord_iou: 0.6074 - val_coord_loss: 0.2662 - val_loss: 0.3179 - val_p_accuracy: 1.0000 - val_p_loss: 1.7057e-06
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.7558 - classes_loss: 0.0309 - coord_iou: 0.7254 - coord_loss: 0.0760 - loss: 0.1069 - p_accuracy: 1.0000 - p_loss: 8.0447e-06 - val_classes_accuracy: 0.6571 - val_classes_loss: 0.0391 - val_coord_iou: 0.6024 - val_coord_loss: 0.2726 - val_loss: 0.3229 - val_p_accuracy: 1.0000 - val_p_loss: 2.8964e-06
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.7800 - classes_loss: 0.0296 - coord_iou: 0.7249 - coord_loss: 0.0764 - loss: 0.1060 - p_accuracy: 1.0000 - p_loss: 9.1892e-06 - val_classes_accuracy: 0.6952 - val_classes_loss: 0.0391 - val_coord_iou: 0.5935 - val_coord_loss: 0.2707 - val_loss: 0.3231 - val_p_accuracy: 1.0000 - val_p_loss: 1.7684e-06
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.8134 - classes_loss: 0.0273 - coord_iou: 0.7449 - coord_loss: 0.0648 - loss: 0.0921 - p_accuracy: 1.0000 - p_loss: 5.8447e-06 - val_classes_accuracy: 0.6952 - val_classes_loss: 0.0382 - val_coord_iou: 0.6132 - val_coord_loss: 0.2565 - val_loss: 0.3069 - val_p_accuracy: 1.0000 - val_p_loss: 2.7541e-06
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.8177 - classes_loss: 0.0263 - coord_iou: 0.7420 - coord_loss: 0.0657 - loss: 0.0921 - p_accuracy: 1.0000 - p_loss: 5.6580e-06 - val_classes_accuracy: 0.6667 - val_classes_loss: 0.0364 - val_coord_iou: 0.6145 - val_coord_loss: 0.2548 - val_loss: 0.3048 - val_p_accuracy: 1.0000 - val_p_loss: 1.9308e-06
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.8367 - classes_loss: 0.0241 - coord_iou: 0.7732 - coord_loss: 0.0509 - loss: 0.0750 - p_accuracy: 1.0000 - p_loss: 3.8407e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0366 - val_coord_iou: 0.6082 - val_coord_loss: 0.2596 - val_loss: 0.3087 - val_p_accuracy: 1.0000 - val_p_loss: 2.1665e-06
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.8458 - classes_loss: 0.0225 - coord_iou: 0.7474 - coord_loss: 0.0568 - loss: 0.0793 - p_accuracy: 1.0000 - p_loss: 5.0767e-06 - val_classes_accuracy: 0.6667 - val_classes_loss: 0.0375 - val_coord_iou: 0.6230 - val_coord_loss: 0.2523 - val_loss: 0.3015 - val_p_accuracy: 1.0000 - val_p_loss: 1.6056e-06
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.8560 - classes_loss: 0.0222 - coord_iou: 0.7752 - coord_loss: 0.0490 - loss: 0.0712 - p_accuracy: 1.0000 - p_loss: 5.6148e-06 - val_classes_accuracy: 0.6810 - val_classes_loss: 0.0363 - val_coord_iou: 0.6128 - val_coord_loss: 0.2440 - val_loss: 0.2921 - val_p_accuracy: 1.0000 - val_p_loss: 1.0452e-06
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.8581 - classes_loss: 0.0211 - coord_iou: 0.7729 - coord_loss: 0.0478 - loss: 0.0690 - p_accuracy: 1.0000 - p_loss: 3.4255e-06 - val_classes_accuracy: 0.7333 - val_classes_loss: 0.0347 - val_coord_iou: 0.6125 - val_coord_loss: 0.2582 - val_loss: 0.3037 - val_p_accuracy: 1.0000 - val_p_loss: 1.2326e-06
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - classes_accuracy: 0.8819 - classes_loss: 0.0185 - coord_iou: 0.7815 - coord_loss: 0.0459 - loss: 0.0643 - p_accuracy: 1.0000 - p_loss: 3.8302e-06 - val_classes_accuracy: 0.7286 - val_classes_loss: 0.0340 - val_coord_iou: 0.6224 - val_coord_loss: 0.2516 - val_loss: 0.2987 - val_p_accuracy: 1.0000 - val_p_loss: 1.4684e-06
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.8964 - classes_loss: 0.0173 - coord_iou: 0.7802 - coord_loss: 0.0457 - loss: 0.0630 - p_accuracy: 1.0000 - p_loss: 4.2140e-06 - val_classes_accuracy: 0.7048 - val_classes_loss: 0.0344 - val_coord_iou: 0.5793 - val_coord_loss: 0.2691 - val_loss: 0.3171 - val_p_accuracy: 1.0000 - val_p_loss: 2.0454e-06
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9016 - classes_loss: 0.0165 - coord_iou: 0.7744 - coord_loss: 0.0428 - loss: 0.0593 - p_accuracy: 1.0000 - p_loss: 3.0349e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0336 - val_coord_iou: 0.6192 - val_coord_loss: 0.2572 - val_loss: 0.2999 - val_p_accuracy: 1.0000 - val_p_loss: 1.9830e-06
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.9048 - classes_loss: 0.0151 - coord_iou: 0.7942 - coord_loss: 0.0389 - loss: 0.0540 - p_accuracy: 1.0000 - p_loss: 3.1097e-06 - val_classes_accuracy: 0.6857 - val_classes_loss: 0.0351 - val_coord_iou: 0.6208 - val_coord_loss: 0.2521 - val_loss: 0.3010 - val_p_accuracy: 1.0000 - val_p_loss: 1.2822e-06
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.9121 - classes_loss: 0.0150 - coord_iou: 0.7933 - coord_loss: 0.0361 - loss: 0.0512 - p_accuracy: 1.0000 - p_loss: 2.9468e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0352 - val_coord_iou: 0.6084 - val_coord_loss: 0.2655 - val_loss: 0.3123 - val_p_accuracy: 1.0000 - val_p_loss: 1.2408e-06
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.9226 - classes_loss: 0.0130 - coord_iou: 0.7833 - coord_loss: 0.0403 - loss: 0.0534 - p_accuracy: 1.0000 - p_loss: 2.7790e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0329 - val_coord_iou: 0.6370 - val_coord_loss: 0.2415 - val_loss: 0.2853 - val_p_accuracy: 1.0000 - val_p_loss: 2.8730e-06
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.9226 - classes_loss: 0.0135 - coord_iou: 0.8008 - coord_loss: 0.0343 - loss: 0.0478 - p_accuracy: 1.0000 - p_loss: 2.4862e-06 - val_classes_accuracy: 0.6952 - val_classes_loss: 0.0340 - val_coord_iou: 0.6302 - val_coord_loss: 0.2546 - val_loss: 0.2997 - val_p_accuracy: 1.0000 - val_p_loss: 2.4060e-06
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9381 - classes_loss: 0.0119 - coord_iou: 0.7961 - coord_loss: 0.0370 - loss: 0.0490 - p_accuracy: 1.0000 - p_loss: 2.5828e-06 - val_classes_accuracy: 0.7238 - val_classes_loss: 0.0318 - val_coord_iou: 0.6238 - val_coord_loss: 0.2540 - val_loss: 0.2977 - val_p_accuracy: 1.0000 - val_p_loss: 9.9154e-07
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9375 - classes_loss: 0.0110 - coord_iou: 0.8093 - coord_loss: 0.0319 - loss: 0.0428 - p_accuracy: 1.0000 - p_loss: 2.9164e-06 - val_classes_accuracy: 0.7381 - val_classes_loss: 0.0324 - val_coord_iou: 0.6180 - val_coord_loss: 0.2521 - val_loss: 0.2977 - val_p_accuracy: 1.0000 - val_p_loss: 2.5731e-06
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.9408 - classes_loss: 0.0102 - coord_iou: 0.8035 - coord_loss: 0.0349 - loss: 0.0452 - p_accuracy: 1.0000 - p_loss: 2.6253e-06 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.0316 - val_coord_iou: 0.6301 - val_coord_loss: 0.2417 - val_loss: 0.2866 - val_p_accuracy: 1.0000 - val_p_loss: 1.5133e-06
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - classes_accuracy: 0.9492 - classes_loss: 0.0094 - coord_iou: 0.8010 - coord_loss: 0.0325 - loss: 0.0419 - p_accuracy: 1.0000 - p_loss: 2.4699e-06 - val_classes_accuracy: 0.7333 - val_classes_loss: 0.0310 - val_coord_iou: 0.6269 - val_coord_loss: 0.2472 - val_loss: 0.2908 - val_p_accuracy: 1.0000 - val_p_loss: 1.6010e-06
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9584 - classes_loss: 0.0078 - coord_iou: 0.8234 - coord_loss: 0.0267 - loss: 0.0345 - p_accuracy: 1.0000 - p_loss: 1.7722e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0314 - val_coord_iou: 0.6393 - val_coord_loss: 0.2477 - val_loss: 0.2923 - val_p_accuracy: 1.0000 - val_p_loss: 1.7530e-06
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9588 - classes_loss: 0.0078 - coord_iou: 0.8155 - coord_loss: 0.0301 - loss: 0.0379 - p_accuracy: 1.0000 - p_loss: 1.7758e-06 - val_classes_accuracy: 0.7286 - val_classes_loss: 0.0321 - val_coord_iou: 0.6256 - val_coord_loss: 0.2502 - val_loss: 0.2927 - val_p_accuracy: 1.0000 - val_p_loss: 2.5470e-06
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9541 - classes_loss: 0.0077 - coord_iou: 0.8061 - coord_loss: 0.0326 - loss: 0.0404 - p_accuracy: 1.0000 - p_loss: 2.1021e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0342 - val_coord_iou: 0.6351 - val_coord_loss: 0.2396 - val_loss: 0.2866 - val_p_accuracy: 1.0000 - val_p_loss: 7.8258e-07
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9601 - classes_loss: 0.0073 - coord_iou: 0.8241 - coord_loss: 0.0253 - loss: 0.0326 - p_accuracy: 1.0000 - p_loss: 1.7495e-06 - val_classes_accuracy: 0.7286 - val_classes_loss: 0.0319 - val_coord_iou: 0.6370 - val_coord_loss: 0.2386 - val_loss: 0.2855 - val_p_accuracy: 1.0000 - val_p_loss: 5.5071e-07
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9661 - classes_loss: 0.0070 - coord_iou: 0.8159 - coord_loss: 0.0276 - loss: 0.0346 - p_accuracy: 1.0000 - p_loss: 1.6672e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0357 - val_coord_iou: 0.6375 - val_coord_loss: 0.2601 - val_loss: 0.3079 - val_p_accuracy: 1.0000 - val_p_loss: 1.2402e-06
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9697 - classes_loss: 0.0060 - coord_iou: 0.8286 - coord_loss: 0.0261 - loss: 0.0321 - p_accuracy: 1.0000 - p_loss: 1.8985e-06 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.0343 - val_coord_iou: 0.6343 - val_coord_loss: 0.2559 - val_loss: 0.3029 - val_p_accuracy: 1.0000 - val_p_loss: 2.6177e-06
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9731 - classes_loss: 0.0057 - coord_iou: 0.8184 - coord_loss: 0.0265 - loss: 0.0321 - p_accuracy: 1.0000 - p_loss: 1.6263e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0336 - val_coord_iou: 0.6408 - val_coord_loss: 0.2384 - val_loss: 0.2839 - val_p_accuracy: 1.0000 - val_p_loss: 1.3324e-06
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9726 - classes_loss: 0.0055 - coord_iou: 0.8218 - coord_loss: 0.0275 - loss: 0.0330 - p_accuracy: 1.0000 - p_loss: 1.8668e-06 - val_classes_accuracy: 0.7381 - val_classes_loss: 0.0325 - val_coord_iou: 0.6470 - val_coord_loss: 0.2603 - val_loss: 0.2993 - val_p_accuracy: 1.0000 - val_p_loss: 4.3286e-06
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9770 - classes_loss: 0.0047 - coord_iou: 0.8245 - coord_loss: 0.0263 - loss: 0.0309 - p_accuracy: 1.0000 - p_loss: 1.4614e-06 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.0326 - val_coord_iou: 0.6459 - val_coord_loss: 0.2460 - val_loss: 0.2915 - val_p_accuracy: 1.0000 - val_p_loss: 1.1127e-06
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9826 - classes_loss: 0.0043 - coord_iou: 0.8334 - coord_loss: 0.0241 - loss: 0.0284 - p_accuracy: 1.0000 - p_loss: 1.2994e-06 - val_classes_accuracy: 0.7286 - val_classes_loss: 0.0307 - val_coord_iou: 0.6227 - val_coord_loss: 0.2497 - val_loss: 0.2942 - val_p_accuracy: 1.0000 - val_p_loss: 6.4265e-07
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9810 - classes_loss: 0.0039 - coord_iou: 0.8394 - coord_loss: 0.0218 - loss: 0.0256 - p_accuracy: 1.0000 - p_loss: 1.0734e-06 - val_classes_accuracy: 0.7238 - val_classes_loss: 0.0315 - val_coord_iou: 0.6477 - val_coord_loss: 0.2394 - val_loss: 0.2847 - val_p_accuracy: 1.0000 - val_p_loss: 1.6223e-06
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9884 - classes_loss: 0.0035 - coord_iou: 0.8351 - coord_loss: 0.0225 - loss: 0.0261 - p_accuracy: 1.0000 - p_loss: 1.5120e-06 - val_classes_accuracy: 0.7143 - val_classes_loss: 0.0348 - val_coord_iou: 0.6385 - val_coord_loss: 0.2404 - val_loss: 0.2888 - val_p_accuracy: 1.0000 - val_p_loss: 8.0366e-07
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - classes_accuracy: 0.9805 - classes_loss: 0.0037 - coord_iou: 0.8349 - coord_loss: 0.0220 - loss: 0.0258 - p_accuracy: 1.0000 - p_loss: 8.6839e-07 - val_classes_accuracy: 0.7190 - val_classes_loss: 0.0354 - val_coord_iou: 0.6401 - val_coord_loss: 0.2407 - val_loss: 0.2876 - val_p_accuracy: 1.0000 - val_p_loss: 4.0967e-07

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_iou')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("--------------------------------------------")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# /tmp/ipykernel_65303/674476821.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i, 0] = y_pred_presence[i]
# La précision globale est de 60.5%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.37    |  0.32  |   0.34   |
# --------------------------------------------
# | VEREUR |   0.67    |  0.64  |   0.65   |
# --------------------------------------------
# | ECUROU |   0.87    |  0.91  |   0.89   |
# --------------------------------------------
# | PIEBAV |   0.90    |  0.86  |   0.88   |
# --------------------------------------------
# | SITTOR |   0.62    |  0.36  |   0.46   |
# --------------------------------------------
# | PINARB |   0.78    |  0.82  |   0.80   |
# --------------------------------------------
# | MESNOI |   0.36    |  0.64  |   0.46   |
# --------------------------------------------
# | MESNON |   0.33    |  0.41  |   0.37   |
# --------------------------------------------
# | MESBLE |   0.31    |  0.23  |   0.26   |
# --------------------------------------------
# | ROUGOR |   0.73    |  0.76  |   0.74   |
# --------------------------------------------
# | ACCMOU |   0.70    |  0.73  |   0.71   |
# --------------------------------------------

# %% [markdown]
# **Travail à faire** : lancez un nouvel apprentissage avec l'augmentation de données. Vous remplacerez, dans l'appel à la fonction ```fit```, les variables ```x_train``` et ```y_train``` par l'unique variable ```train_gen```.
#
#
# Vous devriez observer une nouvelle amélioration des résultats.

# %% [markdown]
# ### Transfert d'apprentissage

# %% [markdown]
# Nous avons vu en première année comment le transfert d'apprentissage pouvait également améliorer les résultats et limiter le sur-apprentissage. L'utilisation d'un réseau pré-entraîné permet souvent de mieux généraliser.
#
# Le bloc suivant permet de charger l'architecture du réseau VGG-16 :

# %% [markdown]
# Une fois cette base convolutive chargée, vous pouvez créer un nouveau modèle en y adjoignant les couches de sortie que vous avez déjà créées lors de la séance précédente
#
# ```
# input_layer = Input(shape=input_shape)
# vgg = conv_base(input_layer)
# ...
# ```

# %% [markdown]
# **Travail à faire**
#
# Testez maintenant l'entraînement de ce réseau, en utilisant également l'augmentation de données. A vous de voir en fonction de vos premiers résultats quelle est la meilleure fonction de coût à utiliser.
#
# Vous devriez obtenir un résultats avoisinant les 80% de bonnes détections.

# %%
def create_model_localisation_with_transfer_learning(input_shape=(64, 64, 3)):

  input_layer = Input(shape=input_shape)

  vgg = conv_base(input_layer)

  """ conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(vgg)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = Conv2D(96, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
  pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

  conv5 = Conv2D(160, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
  pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)

  conv6 = Conv2D(192, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool5)
  pool6 = MaxPooling2D(pool_size=(2, 2))(conv6) """
  # Cette couche vectorise le tenseur de sortie de votre base convolutive, et
  # constituera l'entrée des 3 couches de sortie ci-dessous
  flatten_layer = Flatten()(vgg)

  # amélioration avec cette couche dense
  prev_layer = Dense(2048, activation='relu')(flatten_layer)

  #### Couches de sortie
  output_p = Dense(1, activation='sigmoid', name='p')(prev_layer)   # Sortie caractérisant la présence d'un objet
  output_coord = Dense(4, activation='linear', name='coord')(prev_layer) # Sortie caractérisant les coordonnées de boîte englobante
  output_class = Dense(num_classes, activation='softmax', name='classes')(prev_layer) # Sortie caractérisant les probabilités de classe

  output= [output_p, output_coord, output_class]
  model = Model(input_layer, output)

  print(model.summary())

  return model

# %%
batch_size=16
model = create_model_localisation_with_transfer_learning()
opt = Adam(learning_rate=3e-4)

loss = [keras.losses.MeanSquaredError(), keras.losses.MeanSquaredError(), keras.losses.MeanSquaredError()]
metrics =[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1,1,1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )

with tf.device('/GPU:0'):
    history = model.fit(train_gen,
              epochs=50,
              batch_size=batch_size,
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 2, 2, 512) │ 14,714,688 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_6 (Flatten) │ (None, 2048)      │          0 │ vgg16[3][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 2048)      │  4,196,352 │ flatten_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p (Dense)           │ (None, 1)         │      2,049 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ coord (Dense)       │ (None, 4)         │      8,196 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classes (Dense)     │ (None, 11)        │     22,539 │ dense_5[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,943,824 (72.26 MB)
#  Trainable params: 18,943,824 (72.26 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - classes_accuracy: 0.2751 - classes_loss: 0.0786 - coord_iou: 0.6934 - coord_loss: 0.2198 - loss: 2.4830 - p_accuracy: 0.9581 - p_loss: 0.0512 - val_classes_accuracy: 0.5286 - val_classes_loss: 0.0649 - val_coord_iou: 0.7899 - val_coord_loss: 0.0906 - val_loss: 1.0184 - val_p_accuracy: 1.0000 - val_p_loss: 6.4511e-04
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.6559 - classes_loss: 0.0590 - coord_iou: 0.8883 - coord_loss: 0.0103 - loss: 0.1654 - p_accuracy: 1.0000 - p_loss: 7.4753e-04 - val_classes_accuracy: 0.5952 - val_classes_loss: 0.0503 - val_coord_iou: 0.7384 - val_coord_loss: 0.1130 - val_loss: 1.2367 - val_p_accuracy: 1.0000 - val_p_loss: 2.1905e-04
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.8085 - classes_loss: 0.0399 - coord_iou: 0.8547 - coord_loss: 0.0161 - loss: 0.2023 - p_accuracy: 1.0000 - p_loss: 3.4717e-04 - val_classes_accuracy: 0.7476 - val_classes_loss: 0.0373 - val_coord_iou: 0.7471 - val_coord_loss: 0.1037 - val_loss: 1.1334 - val_p_accuracy: 1.0000 - val_p_loss: 2.6365e-04
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9118 - classes_loss: 0.0248 - coord_iou: 0.8738 - coord_loss: 0.0148 - loss: 0.1737 - p_accuracy: 1.0000 - p_loss: 2.9390e-04 - val_classes_accuracy: 0.7381 - val_classes_loss: 0.0328 - val_coord_iou: 0.7670 - val_coord_loss: 0.1034 - val_loss: 1.0751 - val_p_accuracy: 1.0000 - val_p_loss: 1.8151e-04
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9457 - classes_loss: 0.0181 - coord_iou: 0.8697 - coord_loss: 0.0154 - loss: 0.1730 - p_accuracy: 1.0000 - p_loss: 2.5993e-04 - val_classes_accuracy: 0.7667 - val_classes_loss: 0.0298 - val_coord_iou: 0.7751 - val_coord_loss: 0.1000 - val_loss: 1.0717 - val_p_accuracy: 1.0000 - val_p_loss: 1.5472e-04
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9584 - classes_loss: 0.0132 - coord_iou: 0.8625 - coord_loss: 0.0178 - loss: 0.1928 - p_accuracy: 1.0000 - p_loss: 2.3954e-04 - val_classes_accuracy: 0.7333 - val_classes_loss: 0.0306 - val_coord_iou: 0.7649 - val_coord_loss: 0.0986 - val_loss: 1.0513 - val_p_accuracy: 1.0000 - val_p_loss: 2.1852e-04
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9534 - classes_loss: 0.0141 - coord_iou: 0.8505 - coord_loss: 0.0174 - loss: 0.1890 - p_accuracy: 1.0000 - p_loss: 2.3540e-04 - val_classes_accuracy: 0.7714 - val_classes_loss: 0.0277 - val_coord_iou: 0.7813 - val_coord_loss: 0.0910 - val_loss: 0.9808 - val_p_accuracy: 1.0000 - val_p_loss: 1.0455e-04
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9670 - classes_loss: 0.0090 - coord_iou: 0.8897 - coord_loss: 0.0110 - loss: 0.1193 - p_accuracy: 1.0000 - p_loss: 1.3943e-04 - val_classes_accuracy: 0.7762 - val_classes_loss: 0.0275 - val_coord_iou: 0.7929 - val_coord_loss: 0.0907 - val_loss: 0.9646 - val_p_accuracy: 1.0000 - val_p_loss: 7.7217e-05
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - classes_accuracy: 0.9808 - classes_loss: 0.0069 - coord_iou: 0.8990 - coord_loss: 0.0093 - loss: 0.1005 - p_accuracy: 1.0000 - p_loss: 1.0885e-04 - val_classes_accuracy: 0.7714 - val_classes_loss: 0.0276 - val_coord_iou: 0.7863 - val_coord_loss: 0.0935 - val_loss: 0.9935 - val_p_accuracy: 1.0000 - val_p_loss: 8.7497e-05
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - classes_accuracy: 0.9745 - classes_loss: 0.0075 - coord_iou: 0.8905 - coord_loss: 0.0107 - loss: 0.1148 - p_accuracy: 1.0000 - p_loss: 1.1774e-04 - val_classes_accuracy: 0.7571 - val_classes_loss: 0.0293 - val_coord_iou: 0.7822 - val_coord_loss: 0.0993 - val_loss: 1.0491 - val_p_accuracy: 1.0000 - val_p_loss: 5.9725e-05
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9843 - classes_loss: 0.0059 - coord_iou: 0.9004 - coord_loss: 0.0093 - loss: 0.0987 - p_accuracy: 1.0000 - p_loss: 8.4459e-05 - val_classes_accuracy: 0.7857 - val_classes_loss: 0.0260 - val_coord_iou: 0.7961 - val_coord_loss: 0.0889 - val_loss: 0.9437 - val_p_accuracy: 1.0000 - val_p_loss: 4.4834e-05
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9902 - classes_loss: 0.0041 - coord_iou: 0.9004 - coord_loss: 0.0071 - loss: 0.0749 - p_accuracy: 1.0000 - p_loss: 8.8519e-05 - val_classes_accuracy: 0.7857 - val_classes_loss: 0.0259 - val_coord_iou: 0.7864 - val_coord_loss: 0.0964 - val_loss: 0.9931 - val_p_accuracy: 1.0000 - val_p_loss: 5.8170e-05
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9860 - classes_loss: 0.0046 - coord_iou: 0.9013 - coord_loss: 0.0079 - loss: 0.0842 - p_accuracy: 1.0000 - p_loss: 5.6494e-05 - val_classes_accuracy: 0.7476 - val_classes_loss: 0.0305 - val_coord_iou: 0.7830 - val_coord_loss: 0.0930 - val_loss: 0.9845 - val_p_accuracy: 1.0000 - val_p_loss: 2.4311e-05
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9842 - classes_loss: 0.0042 - coord_iou: 0.8983 - coord_loss: 0.0072 - loss: 0.0761 - p_accuracy: 1.0000 - p_loss: 6.7440e-05 - val_classes_accuracy: 0.7810 - val_classes_loss: 0.0264 - val_coord_iou: 0.7906 - val_coord_loss: 0.0871 - val_loss: 0.9348 - val_p_accuracy: 1.0000 - val_p_loss: 3.5384e-05
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9875 - classes_loss: 0.0037 - coord_iou: 0.9009 - coord_loss: 0.0077 - loss: 0.0813 - p_accuracy: 1.0000 - p_loss: 5.6651e-05 - val_classes_accuracy: 0.7857 - val_classes_loss: 0.0266 - val_coord_iou: 0.7833 - val_coord_loss: 0.0855 - val_loss: 0.9118 - val_p_accuracy: 1.0000 - val_p_loss: 4.0191e-05
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9853 - classes_loss: 0.0038 - coord_iou: 0.9072 - coord_loss: 0.0068 - loss: 0.0716 - p_accuracy: 1.0000 - p_loss: 5.6181e-05 - val_classes_accuracy: 0.7571 - val_classes_loss: 0.0271 - val_coord_iou: 0.7976 - val_coord_loss: 0.0888 - val_loss: 0.9265 - val_p_accuracy: 1.0000 - val_p_loss: 2.5089e-05
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9874 - classes_loss: 0.0030 - coord_iou: 0.9182 - coord_loss: 0.0051 - loss: 0.0545 - p_accuracy: 1.0000 - p_loss: 3.2722e-05 - val_classes_accuracy: 0.7571 - val_classes_loss: 0.0262 - val_coord_iou: 0.7907 - val_coord_loss: 0.0898 - val_loss: 0.9428 - val_p_accuracy: 1.0000 - val_p_loss: 1.6610e-05
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9884 - classes_loss: 0.0024 - coord_iou: 0.9121 - coord_loss: 0.0054 - loss: 0.0563 - p_accuracy: 1.0000 - p_loss: 3.2984e-05 - val_classes_accuracy: 0.7619 - val_classes_loss: 0.0282 - val_coord_iou: 0.7834 - val_coord_loss: 0.1025 - val_loss: 1.0575 - val_p_accuracy: 1.0000 - val_p_loss: 2.6257e-05
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9912 - classes_loss: 0.0028 - coord_iou: 0.9104 - coord_loss: 0.0062 - loss: 0.0649 - p_accuracy: 1.0000 - p_loss: 3.4697e-05 - val_classes_accuracy: 0.7810 - val_classes_loss: 0.0251 - val_coord_iou: 0.7995 - val_coord_loss: 0.0910 - val_loss: 0.9512 - val_p_accuracy: 1.0000 - val_p_loss: 3.5602e-05
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9891 - classes_loss: 0.0030 - coord_iou: 0.8966 - coord_loss: 0.0079 - loss: 0.0821 - p_accuracy: 1.0000 - p_loss: 4.3596e-05 - val_classes_accuracy: 0.7762 - val_classes_loss: 0.0280 - val_coord_iou: 0.7916 - val_coord_loss: 0.0959 - val_loss: 0.9988 - val_p_accuracy: 1.0000 - val_p_loss: 1.8211e-05
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9917 - classes_loss: 0.0025 - coord_iou: 0.9058 - coord_loss: 0.0072 - loss: 0.0745 - p_accuracy: 1.0000 - p_loss: 3.4711e-05 - val_classes_accuracy: 0.8048 - val_classes_loss: 0.0244 - val_coord_iou: 0.7986 - val_coord_loss: 0.0858 - val_loss: 0.9202 - val_p_accuracy: 1.0000 - val_p_loss: 2.4777e-05
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9891 - classes_loss: 0.0027 - coord_iou: 0.8994 - coord_loss: 0.0075 - loss: 0.0776 - p_accuracy: 1.0000 - p_loss: 3.6279e-05 - val_classes_accuracy: 0.7857 - val_classes_loss: 0.0255 - val_coord_iou: 0.7980 - val_coord_loss: 0.0883 - val_loss: 0.9405 - val_p_accuracy: 1.0000 - val_p_loss: 3.3500e-05
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9933 - classes_loss: 0.0024 - coord_iou: 0.9095 - coord_loss: 0.0066 - loss: 0.0688 - p_accuracy: 1.0000 - p_loss: 3.1647e-05 - val_classes_accuracy: 0.8000 - val_classes_loss: 0.0247 - val_coord_iou: 0.7892 - val_coord_loss: 0.0861 - val_loss: 0.8918 - val_p_accuracy: 1.0000 - val_p_loss: 1.6748e-05
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9940 - classes_loss: 0.0024 - coord_iou: 0.9088 - coord_loss: 0.0077 - loss: 0.0799 - p_accuracy: 1.0000 - p_loss: 2.4974e-05 - val_classes_accuracy: 0.7571 - val_classes_loss: 0.0293 - val_coord_iou: 0.7991 - val_coord_loss: 0.0909 - val_loss: 0.9724 - val_p_accuracy: 1.0000 - val_p_loss: 1.9354e-05
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9941 - classes_loss: 0.0022 - coord_iou: 0.9121 - coord_loss: 0.0068 - loss: 0.0698 - p_accuracy: 1.0000 - p_loss: 2.5614e-05 - val_classes_accuracy: 0.7714 - val_classes_loss: 0.0268 - val_coord_iou: 0.7964 - val_coord_loss: 0.0833 - val_loss: 0.8966 - val_p_accuracy: 1.0000 - val_p_loss: 1.1885e-05
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9959 - classes_loss: 0.0024 - coord_iou: 0.9037 - coord_loss: 0.0077 - loss: 0.0790 - p_accuracy: 1.0000 - p_loss: 2.2971e-05 - val_classes_accuracy: 0.7952 - val_classes_loss: 0.0256 - val_coord_iou: 0.7860 - val_coord_loss: 0.0891 - val_loss: 0.9231 - val_p_accuracy: 1.0000 - val_p_loss: 1.7738e-05
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9941 - classes_loss: 0.0023 - coord_iou: 0.9079 - coord_loss: 0.0067 - loss: 0.0698 - p_accuracy: 1.0000 - p_loss: 2.4173e-05 - val_classes_accuracy: 0.7333 - val_classes_loss: 0.0298 - val_coord_iou: 0.7860 - val_coord_loss: 0.0931 - val_loss: 0.9898 - val_p_accuracy: 1.0000 - val_p_loss: 1.5340e-05
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9870 - classes_loss: 0.0029 - coord_iou: 0.9065 - coord_loss: 0.0070 - loss: 0.0728 - p_accuracy: 1.0000 - p_loss: 2.5154e-05 - val_classes_accuracy: 0.7905 - val_classes_loss: 0.0258 - val_coord_iou: 0.7895 - val_coord_loss: 0.0897 - val_loss: 0.9422 - val_p_accuracy: 1.0000 - val_p_loss: 1.5254e-05
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9960 - classes_loss: 0.0017 - coord_iou: 0.9130 - coord_loss: 0.0058 - loss: 0.0601 - p_accuracy: 1.0000 - p_loss: 2.4875e-05 - val_classes_accuracy: 0.7524 - val_classes_loss: 0.0289 - val_coord_iou: 0.7975 - val_coord_loss: 0.0874 - val_loss: 0.9289 - val_p_accuracy: 1.0000 - val_p_loss: 1.2046e-05
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9866 - classes_loss: 0.0030 - coord_iou: 0.9056 - coord_loss: 0.0067 - loss: 0.0696 - p_accuracy: 1.0000 - p_loss: 1.9320e-05 - val_classes_accuracy: 0.7905 - val_classes_loss: 0.0251 - val_coord_iou: 0.8011 - val_coord_loss: 0.0788 - val_loss: 0.8600 - val_p_accuracy: 1.0000 - val_p_loss: 9.5874e-06
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9952 - classes_loss: 0.0014 - coord_iou: 0.9161 - coord_loss: 0.0052 - loss: 0.0534 - p_accuracy: 1.0000 - p_loss: 1.3735e-05 - val_classes_accuracy: 0.7762 - val_classes_loss: 0.0268 - val_coord_iou: 0.8022 - val_coord_loss: 0.0753 - val_loss: 0.8160 - val_p_accuracy: 1.0000 - val_p_loss: 1.0713e-05
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9955 - classes_loss: 0.0015 - coord_iou: 0.9143 - coord_loss: 0.0056 - loss: 0.0574 - p_accuracy: 1.0000 - p_loss: 1.7862e-05 - val_classes_accuracy: 0.8048 - val_classes_loss: 0.0260 - val_coord_iou: 0.8024 - val_coord_loss: 0.0813 - val_loss: 0.8780 - val_p_accuracy: 1.0000 - val_p_loss: 1.2407e-05
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9953 - classes_loss: 0.0016 - coord_iou: 0.9090 - coord_loss: 0.0067 - loss: 0.0685 - p_accuracy: 1.0000 - p_loss: 1.6606e-05 - val_classes_accuracy: 0.7714 - val_classes_loss: 0.0279 - val_coord_iou: 0.7940 - val_coord_loss: 0.0828 - val_loss: 0.9031 - val_p_accuracy: 1.0000 - val_p_loss: 6.7535e-06
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9973 - classes_loss: 0.0012 - coord_iou: 0.9198 - coord_loss: 0.0050 - loss: 0.0513 - p_accuracy: 1.0000 - p_loss: 1.4605e-05 - val_classes_accuracy: 0.7810 - val_classes_loss: 0.0265 - val_coord_iou: 0.7828 - val_coord_loss: 0.0801 - val_loss: 0.8374 - val_p_accuracy: 1.0000 - val_p_loss: 8.6128e-06
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9896 - classes_loss: 0.0026 - coord_iou: 0.8905 - coord_loss: 0.0104 - loss: 0.1071 - p_accuracy: 1.0000 - p_loss: 2.2910e-05 - val_classes_accuracy: 0.7762 - val_classes_loss: 0.0280 - val_coord_iou: 0.7812 - val_coord_loss: 0.0870 - val_loss: 0.8970 - val_p_accuracy: 1.0000 - val_p_loss: 8.5371e-06
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - classes_accuracy: 0.9720 - classes_loss: 0.0053 - coord_iou: 0.8701 - coord_loss: 0.0170 - loss: 0.1754 - p_accuracy: 1.0000 - p_loss: 1.9807e-05 - val_classes_accuracy: 0.5524 - val_classes_loss: 0.0603 - val_coord_iou: 0.6178 - val_coord_loss: 0.2972 - val_loss: 3.1966 - val_p_accuracy: 1.0000 - val_p_loss: 9.1204e-05
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.4902 - classes_loss: 0.0621 - coord_iou: 0.6415 - coord_loss: 0.2155 - loss: 2.2189 - p_accuracy: 1.0000 - p_loss: 3.2786e-04 - val_classes_accuracy: 0.5143 - val_classes_loss: 0.0592 - val_coord_iou: 0.7122 - val_coord_loss: 0.1976 - val_loss: 2.1104 - val_p_accuracy: 1.0000 - val_p_loss: 3.5253e-04
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.6274 - classes_loss: 0.0474 - coord_iou: 0.7579 - coord_loss: 0.0864 - loss: 0.9124 - p_accuracy: 1.0000 - p_loss: 2.3551e-04 - val_classes_accuracy: 0.7286 - val_classes_loss: 0.0374 - val_coord_iou: 0.7812 - val_coord_loss: 0.1033 - val_loss: 1.1218 - val_p_accuracy: 1.0000 - val_p_loss: 1.9114e-05
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.8323 - classes_loss: 0.0250 - coord_iou: 0.8547 - coord_loss: 0.0240 - loss: 0.2653 - p_accuracy: 1.0000 - p_loss: 2.6387e-05 - val_classes_accuracy: 0.7381 - val_classes_loss: 0.0318 - val_coord_iou: 0.8027 - val_coord_loss: 0.0953 - val_loss: 0.9945 - val_p_accuracy: 1.0000 - val_p_loss: 8.5156e-06
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9092 - classes_loss: 0.0138 - coord_iou: 0.8941 - coord_loss: 0.0101 - loss: 0.1146 - p_accuracy: 1.0000 - p_loss: 1.0484e-05 - val_classes_accuracy: 0.7524 - val_classes_loss: 0.0313 - val_coord_iou: 0.8010 - val_coord_loss: 0.0872 - val_loss: 0.9139 - val_p_accuracy: 1.0000 - val_p_loss: 9.2350e-06
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9479 - classes_loss: 0.0093 - coord_iou: 0.9074 - coord_loss: 0.0063 - loss: 0.0724 - p_accuracy: 1.0000 - p_loss: 8.3577e-06 - val_classes_accuracy: 0.7571 - val_classes_loss: 0.0292 - val_coord_iou: 0.8037 - val_coord_loss: 0.0839 - val_loss: 0.8879 - val_p_accuracy: 1.0000 - val_p_loss: 4.8252e-06
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9684 - classes_loss: 0.0061 - coord_iou: 0.9256 - coord_loss: 0.0040 - loss: 0.0464 - p_accuracy: 1.0000 - p_loss: 5.9044e-06 - val_classes_accuracy: 0.7571 - val_classes_loss: 0.0281 - val_coord_iou: 0.7972 - val_coord_loss: 0.0887 - val_loss: 0.9299 - val_p_accuracy: 1.0000 - val_p_loss: 4.5258e-06
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9848 - classes_loss: 0.0039 - coord_iou: 0.9305 - coord_loss: 0.0043 - loss: 0.0474 - p_accuracy: 1.0000 - p_loss: 4.5314e-06 - val_classes_accuracy: 0.7667 - val_classes_loss: 0.0283 - val_coord_iou: 0.8015 - val_coord_loss: 0.0882 - val_loss: 0.9223 - val_p_accuracy: 1.0000 - val_p_loss: 2.9959e-06
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9867 - classes_loss: 0.0030 - coord_iou: 0.9412 - coord_loss: 0.0026 - loss: 0.0288 - p_accuracy: 1.0000 - p_loss: 4.3223e-06 - val_classes_accuracy: 0.7762 - val_classes_loss: 0.0287 - val_coord_iou: 0.7996 - val_coord_loss: 0.0973 - val_loss: 1.0245 - val_p_accuracy: 1.0000 - val_p_loss: 3.5634e-06
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9909 - classes_loss: 0.0024 - coord_iou: 0.9357 - coord_loss: 0.0031 - loss: 0.0337 - p_accuracy: 1.0000 - p_loss: 4.4132e-06 - val_classes_accuracy: 0.7857 - val_classes_loss: 0.0275 - val_coord_iou: 0.8024 - val_coord_loss: 0.0938 - val_loss: 0.9887 - val_p_accuracy: 1.0000 - val_p_loss: 2.7884e-06
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9903 - classes_loss: 0.0021 - coord_iou: 0.9373 - coord_loss: 0.0024 - loss: 0.0264 - p_accuracy: 1.0000 - p_loss: 3.7094e-06 - val_classes_accuracy: 0.7714 - val_classes_loss: 0.0275 - val_coord_iou: 0.8057 - val_coord_loss: 0.0917 - val_loss: 0.9713 - val_p_accuracy: 1.0000 - val_p_loss: 2.6546e-06
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9943 - classes_loss: 0.0016 - coord_iou: 0.9478 - coord_loss: 0.0021 - loss: 0.0225 - p_accuracy: 1.0000 - p_loss: 3.2440e-06 - val_classes_accuracy: 0.7857 - val_classes_loss: 0.0264 - val_coord_iou: 0.8057 - val_coord_loss: 0.0905 - val_loss: 0.9581 - val_p_accuracy: 1.0000 - val_p_loss: 2.4633e-06
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9974 - classes_loss: 8.5325e-04 - coord_iou: 0.9512 - coord_loss: 0.0020 - loss: 0.0208 - p_accuracy: 1.0000 - p_loss: 2.9281e-06 - val_classes_accuracy: 0.7714 - val_classes_loss: 0.0279 - val_coord_iou: 0.8038 - val_coord_loss: 0.0887 - val_loss: 0.9413 - val_p_accuracy: 1.0000 - val_p_loss: 2.6799e-06
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - classes_accuracy: 0.9937 - classes_loss: 0.0014 - coord_iou: 0.9512 - coord_loss: 0.0021 - loss: 0.0220 - p_accuracy: 1.0000 - p_loss: 3.6373e-06 - val_classes_accuracy: 0.7810 - val_classes_loss: 0.0271 - val_coord_iou: 0.8049 - val_coord_loss: 0.0885 - val_loss: 0.9409 - val_p_accuracy: 1.0000 - val_p_loss: 2.1410e-06
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - classes_accuracy: 0.9965 - classes_loss: 9.7102e-04 - coord_iou: 0.9474 - coord_loss: 0.0041 - loss: 0.0420 - p_accuracy: 1.0000 - p_loss: 3.1944e-06 - val_classes_accuracy: 0.7905 - val_classes_loss: 0.0279 - val_coord_iou: 0.8040 - val_coord_loss: 0.0949 - val_loss: 1.0207 - val_p_accuracy: 1.0000 - val_p_loss: 1.7726e-06

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_iou')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("--------------------------------------------")
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e9cb43ac9a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# /tmp/ipykernel_65303/674476821.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i, 0] = y_pred_presence[i]
# La précision globale est de 73.8%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.46    |  0.55  |   0.50   |
# --------------------------------------------
# | VEREUR |   0.90    |  0.86  |   0.88   |
# --------------------------------------------
# | ECUROU |   0.90    |  0.86  |   0.88   |
# --------------------------------------------
# | PIEBAV |   1.00    |  0.95  |   0.98   |
# --------------------------------------------
# | SITTOR |   0.82    |  0.64  |   0.72   |
# --------------------------------------------
# | PINARB |   0.86    |  0.86  |   0.86   |
# --------------------------------------------
# | MESNOI |   0.75    |  0.64  |   0.69   |
# --------------------------------------------
# | MESNON |   0.51    |  0.82  |   0.63   |
# --------------------------------------------
# | MESBLE |   0.64    |  0.32  |   0.42   |
# --------------------------------------------
# | ROUGOR |   0.79    |  0.71  |   0.75   |
# --------------------------------------------
# | ACCMOU |   0.68    |  0.86  |   0.76   |
# --------------------------------------------

# %% [markdown]
# # Détection d'objet : version simplifiée de YOLO
#
# <center> <img src="https://drive.google.com/thumbnail?id=1V4aAS7K_Akj83apuMZ2vRjNvjgdgoOCh&sz=w1000" width=500></center>
# <caption><center> Pipeline de l'algorithme YOLO ([Redmon 2016]) </center></caption>
#
# Dans cette partie, nous allons tenter d'aller un peu plus loin en considérant le problème plus complexe de la détection d'objet, c'est-à-dire de la localisation et la classification conjointe de tous les objets dans l'image ; pour cela nous allons implémenter une version simplifiée de YOLO. Cette version est considérée simplifiée car ne reprenant pas l'intégralité des éléments décrite dans l'article de Redmon (par exemple, sur le choix de l'optimiseur). Une des simplifications principales est également que nous ne considérerons **qu'un objet par cellule**.
#
# Pour rappel, l'idée de YOLO est de découper l'image en une grille de cellules et de réaliser une prédiction de plusieurs boîtes englobantes ainsi qu'une classification par cellule. La vidéo de la cellule suivante rappelle les concepts vus en cours sur YOLO et la détection d'objet en général.

# %% [markdown]
# Récupération des données

# %%
# !git clone https://github.com/axelcarlier/wildlife.git
# Out:
# Cloning into 'wildlife'...
# remote: Enumerating objects: 2973, done.
# remote: Total 2973 (delta 0), reused 0 (delta 0), pack-reused 2973 (from 1)
# Receiving objects: 100% (2973/2973), 433.18 MiB | 47.28 MiB/s, done.
# Updating files: 100% (3008/3008), done.

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# Définition des différentes variables utiles pour la suite

# %%
IMAGE_SIZE = 64 # Dimension des images en entrée du réseau
CELL_PER_DIM = 8 # Nombre de cellules en largeur et en hauteur
BOX_PER_CELL = 1 # Nombre d'objets par cellule
NB_CLASSES = 4 # Nombre de classes du problème
PIX_PER_CELL = round(IMAGE_SIZE/CELL_PER_DIM)

CLASS_LABELS = ['buffalo', 'elephant', 'rhino', 'zebra']

# %% [markdown]
# ### Chargement des données
#
# On charge les images dans la dimension demandée, dans un tenseur $x$. Pour les labels, on ne les structure pas directement dans le format YOLO, mais on les place dans une liste de liste de listes : la longueur de la liste parente est celle du nombre d'images de la base, celle de la liste intermédiaire est celle du nombre d'objets d'une image donnée, et enfin la liste de plus bas niveau a une longueur 5 et contiendra les coordonnées de boîte englobante et les labels de classe associés.

# %%
import numpy as np

import math


import PIL
from PIL import Image
import glob, os, sys

for file in glob.glob("*.txt"):
    print(file)

def load_data_detection(ds_path):

  y_paths = []
  # Détermination du nombre d'images total
  for c in CLASS_LABELS:
    path = ds_path + c + '/'
    for file in os.listdir(path):
      if file.endswith('.txt'):
          y_paths.append(os.path.join(path, file))

  dataset_size = len(y_paths)

  # Préparation des structures de données pour x et y
  x = np.zeros((dataset_size, IMAGE_SIZE, IMAGE_SIZE, 3))
  y = []

  for i in range(len(y_paths)):
    text_path = y_paths[i]
    img_path = text_path[:-3] + 'jpg'

    if not os.path.exists(img_path):
      img_path = text_path[:-3] + 'JPG'

    # Lecture de l'image : on va remplir la variable x
    # Lecture de l'image
    img = Image.open(img_path)
    # Mise à l'échelle de l'image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE), Image.Resampling.LANCZOS)
    # Remplissage de la variable x
    x[i] = np.asarray(img, dtype=np.int32)

    # Texte : coordonnées de boîtes englobantes pour remplir y
    boxes = []
    # Texte : coordonnées de boîtes englobantes pour remplir y
    text_file = open(text_path, "r")
    # Récupération des lignes du fichier texte
    rows = text_file.read().split('\n')
    # Parcours de chaque ligne
    for row in rows:
      if row != '':
        # Séparation des différentes informations
        row = list(row.split(' '))
        box = []
        # réorganisation : les 4 coordonnées de boîte englobantes (castées en flottants) d'abord
        for r in row[1:]:
          box.append(float(r))

        box_normal = [box[0]-box[2]/2, box[1]-box[3]/2, box[0]+box[2]/2, box[1]+box[3]/2]

        # Puis le label de classe (casté en entier) à la suite
        box.append(int(row[0]))
        boxes.append(box)

    y.append(boxes)
  return x, y

# Chemin vers la base de données
ds_path = "./wildlife/"
x ,y = load_data_detection(ds_path)

# %% [markdown]
# ### Affichage des données
#
# Le code ci-dessous vous permettra d'afficher les images ainsi que leurs boîtes englobantes associées. On peut spécifier l'id d'une image en particulier ou, si l'on en spécifie pas, visualiser une image aléatoire.

# %%
from scipy.special import softmax
import matplotlib.pyplot as plt

def print_data_detection(x, y, id=None, classes=CLASS_LABELS, image_size=IMAGE_SIZE):
  if id==None:
    # Tirage aléatoire d'une image dans la base
    num_img = np.random.randint(x.shape[0])
  else:
    num_img = id

  img = x[num_img]
  if np.max(img) > 1:
    img = img/255
  boxes = y[num_img]

  colors = ["blue", "yellow", "red", "orange"] # Différentes couleurs pour les différentes classes

  # Affichage de l'image
  plt.imshow(img)
  for box in boxes:

    # Détermination de la classe
    class_id = box[4]

    # Détermination des extrema de la boîte englobante
    p_x = [(box[0]-box[2]/2) * IMAGE_SIZE, (box[0]+box[2]/2) * IMAGE_SIZE]
    p_y = [(box[1]-box[3]/2) * IMAGE_SIZE, (box[1]+box[3]/2) * IMAGE_SIZE]

    # Affichage de la boîte englobante, dans la bonne couleur
    plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
    plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
    plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
    plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id], label=classes[class_id])
    #plt.title("Vérité Terrain : Image {}".format(num_img, classes[class_id]))

  plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
  plt.axis('off')
  plt.show()


print_data_detection(x, y)

# %% [markdown]
# ### Écriture des labels au format YOLO
#
# Les deux fonctions ci-dessous sont essentielles car elles permettent de convertir les boîtes englobantes dans le format adopté par YOLO (voir la section Modèle un peu plus bas), mais également de faire l'opération inverse afin d'interpréter la sortie du réseau.
#
# Notez que la fonction *get_box_from_yolo* intègre dans les boîtes englobantes une information supplémentaire par rapport aux données chargées initialement : la probabilité de présence associée à la boîte englobante.
#
# **Travail à faire**
# -   Lisez attentivement la fonction ```set_box_for_yolo``` afin de bien comprendre comment les boîtes englobantes sont rangées dans le tenseur YOLO
# -   Écrivez la fonction ```get_box_from_yolo``` pour lire les informations dans le tenseur YOLO et créer la liste boîtes englobantes associées.

# %%
from tensorflow.keras.utils import to_categorical
from scipy.special import expit, softmax


# Ecrit la liste de boîtes englobantes dans le tenseur YOLO
def set_box_for_yolo(y, num_classes=NB_CLASSES, image_size=IMAGE_SIZE, cell_size=PIX_PER_CELL):
  nb_cells_per_dim = round(image_size/cell_size)

  y_YOLO = np.zeros((len(y), nb_cells_per_dim, nb_cells_per_dim, 1 + 4 + num_classes))

  for i in range(len(y)):
    for box in y[i]:
      # Coordonnées du centre de la boîte englobante dans le repère image
      cx, cy = box[0] * image_size, box[1] * image_size
      # Détermination des indices de la cellule dans laquelle tombe le centre
      ind_x, ind_y = int(cx // cell_size), int(cy // cell_size)
      # YOLO : "The (x, y) coordinates represent the center of the box relative to the bounds of the grid cell."
      # On va donc calculer les coordonnées du centre relativement à la cellule dans laquelle il se situe
      y_YOLO[i, ind_x, ind_y, 1] = (cx - ind_x * cell_size) / cell_size
      y_YOLO[i, ind_x, ind_y, 2] = (cy - ind_y * cell_size) / cell_size
      # Largeur et hauteur de boîte
      y_YOLO[i, ind_x, ind_y, 3] = box[2]
      y_YOLO[i, ind_x, ind_y, 4] = box[3]

      # Indice de confiance de la boîte englobante pour la cellule correspondante
      y_YOLO[i, ind_x, ind_y, 0] = 1
      # On range les probabilités de classe à la fin du vecteur ([ Présence ; cx ; cy ; w ; h ; CLASSES])
      y_YOLO[i, ind_x, ind_y, 5:] = to_categorical(box[4], num_classes=num_classes)

  return y_YOLO

# Renvoit une liste de boîtes englobantes à partir d'un tenseur YOLO.
# Si mode = 'pred', il s'agit d'une prédiction du réseau, il faut alors utiliser la fonction sigmoide
# pour obtenir la présence prédite, et la fonction softmax pour obtenir les probabilités de classe
# Dans tous les cas, on renvoit uniquement les boîtes englobantes donc l'indice de confiance excède
# le seuil confidence_threshold
def get_box_from_yolo(y_YOLO, mode=None, confidence_threshold=0.5, num_classes=NB_CLASSES, image_size=IMAGE_SIZE, cell_size=PIX_PER_CELL):
  nb_cells_per_dim = round(image_size/cell_size)
  y = []

  for i in range(len(y_YOLO)):
    for ind_x in range(nb_cells_per_dim):
      for ind_y in range(nb_cells_per_dim):
        if y_YOLO[i, ind_x, ind_y, 0] > confidence_threshold:
          box = []
          # Coordonnées du centre de la boîte englobante dans le repère image
          cx = (y_YOLO[i, ind_x, ind_y, 1] * cell_size) + ind_x * cell_size
          cy = (y_YOLO[i, ind_x, ind_y, 2] * cell_size) + ind_y * cell_size
          box.append(cx / image_size)
          box.append(cy / image_size)
          # Largeur et hauteur de boîte
          box.append(y_YOLO[i, ind_x, ind_y, 3])
          box.append(y_YOLO[i, ind_x, ind_y, 4])
          
          if mode == 'pred':
            # Probabilités des classes
            box.append(softmax(y_YOLO[i, ind_x, ind_y, 5:]))
            # Présence prédite
            box.append(expit(y_YOLO[i, ind_x, ind_y, 0]))
          else:
            # Indix classe majoritaire
            box.append(np.argmax(y_YOLO[i,ind_x,ind_y,5:]))
            # Présence
            box.append(y_YOLO[i, ind_x, ind_y, 0])
          y.append([box])
  
  return y

# On s'assure de pouvoir passer d'une représentation à l'autre sans altérer les données
print(y[:2])
print(get_box_from_yolo(set_box_for_yolo(y[:2])))
# Out:
# [[[0.56, 0.663017, 0.6175, 0.644769, 0]], [[0.473515, 0.508434, 0.497592, 0.838554, 0]]]
# [[[np.float64(0.56), np.float64(0.663017), np.float64(0.6175), np.float64(0.644769), np.int64(0), np.float64(1.0)]], [[np.float64(0.473515), np.float64(0.508434), np.float64(0.497592), np.float64(0.838554), np.int64(0), np.float64(1.0)]]]

# %% [markdown]
# **Résultat attendu**
# ```
# [[[0.483984, 0.522973, 0.749219, 0.645946, 0]], [[0.509375, 0.649324, 0.80625, 0.595946, 0]]]
# [[[0.483984, 0.522973, 0.749219, 0.645946, 0, 1.0]], [[0.509375, 0.649324, 0.80625, 0.595946, 0, 1.0]]]
# ```

# %% [markdown]
# **Fin de la séance 2**
#
#
# ---

# %% [markdown]
# ### Augmentation de données
#
# Dans la cellule ci-dessous, il vous faudra intégrer les augmentations que vous aurez choisi. **Attention, ne faites cette partie que dans un second temps, lorsque vous aurez une première version du réseau qui fonctionnera !**
#
# Aidez-vous de [cette page](https://albumentations.ai/docs/getting_started/transforms_and_targets/) pour déterminer des augmentations qui peuvent fonctionner.

# %%
from albumentations import (Compose, ShiftScaleRotate, HorizontalFlip)
import albumentations as A

AUGMENTATIONS_TRAIN = Compose([
    #### A COMPLETER, MAIS SEULEMENT LORSQUE VOUS AVEZ UN RESEAU QUI (SUR-)APPREND !
    # HorizontalFlip(p=0.5),
    # ...
], bbox_params=A.BboxParams(format='yolo'))

# %% [markdown]
# L'objet ```Sequence``` défini ci-dessous nous permettra la mise en batch de nos données. Il est très similaire à celui de la localisation d'objet mais il utilise les fonctions ```set_box_for_yolo``` et ```get_box_from_yolo```

# %%
from tensorflow.keras.utils import Sequence

class YOLOSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_set, y_set, batch_size,augmentations):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(x_set.shape[0], dtype='int')
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))


    # Il y a des problèmes d'arrondi dans les conversions de boîtes englobantes
    # internes à la librairie Albumentations
    # Pour les contourner, si les boîtes sont trop proches des bords, on les érode un peu
    def erode_bounding_box(self, box, epsilon = 0.02):
        eroded_box = []

        xmin = max(box[0] - box[2]/2, epsilon)
        ymin = max(box[1] - box[3]/2, epsilon)
        xmax = min(box[0] + box[2]/2, 1-epsilon)
        ymax = min(box[1] + box[3]/2, 1-epsilon)

        cx = xmin + (xmax - xmin)/2
        cy = ymin + (ymax - ymin)/2
        width = xmax - xmin
        height = ymax - ymin

        eroded_box = [cx, cy, width, height, box[4]]
        return eroded_box

    # Application de l'augmentation de données à chaque image du batch et aux
    # boîtes englobantes associées
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
        batch_y = []

        # Pour chaque image du batch
        for i in range(len(bx)):
            boxes = []
            # Erosion des boîtes englobantes
            for box in by[i]:
              boxes.append(self.erode_bounding_box(box))

            # Application de l'augmentation à l'image et aux boîtes englobantes
            transformed = self.augment(image=bx[i].astype('float32'), bboxes=boxes)
            batch_x[i] = transformed['image']
            batch_y_transformed = transformed['bboxes']
            batch_y.append(batch_y_transformed)

        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    def __getitem__(self, idx):
        # Sélection des indices des données du prochain batch
        batch_indices = self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]
        # Récupération des données puis des labels du batch
        batch_x = self.x[batch_indices]
        batch_boxes = [self.y[item] for item in list(batch_indices)]
        # Application de l'augmentation de données
        batch_x_aug, batch_boxes_aug = self.apply_augmentation(batch_x, batch_boxes)

        # Préparation des données pour le réseau :
        # Normalisation des entrées
        batch_x_aug = batch_x_aug/255
        # Passage des sorties au format YOLO
        batch_y_YOLO = set_box_for_yolo(batch_boxes_aug)

        return np.array(batch_x_aug), batch_y_YOLO

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %%
# Instanciation d'une Sequence
train_gen = YOLOSequence(x[:1], y[:1], 1, augmentations=AUGMENTATIONS_TRAIN)

# Pour tester la séquence, nous sélectionnons les éléments du premier batch et les affichons
batch_x, batch_y = train_gen.__getitem__(0)

print_data_detection(batch_x, get_box_from_yolo(batch_y))

# %% [markdown]
# ## Implémentation de YOLO
#
# ### Modèle
#
# <center> <img src="https://drive.google.com/thumbnail?id=1_wXc_gTIAr37STaxu3chq1EEjVSKv6a5&sz=w1000" width=500></center>
# <caption><center> Illustration de la couche de sortie de YOLO. </center></caption>
#
# Le modèle que je vous propose ci-dessous n'est qu'une possibilité parmi beaucoup d'autres.
# A vous de compléter la dernière couche pour avoir une sortie de la bonne dimension.
#
# **Remarque importante** : comme le tenseur de sortie de YOLO est un peu complexe à manipuler, on choisit ici de regrouper l'ensemble des prédictions dans une seule et même sortie, ce qui nous oblige à utiliser la même fonction d'activation pour toutes nos sorties. On utilisera donc l'activation **linéaire** pour toutes ces sorties. On appliquera les fonctions sigmoïde et softmax pour les sorties "présence" et "probablités de classe" directement dans la fonction de coût !

# %%
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Reshape, Dropout, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers


def create_model_YOLO(input_shape=(64, 64, 3)):
  input_layer = Input(shape=input_shape)

  conv1 = Conv2D(32, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
  conv1 = Conv2D(32, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = Conv2D(64, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
  conv2 = Conv2D(64, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = Conv2D(128, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
  conv3 = Conv2D(128, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  conv4 = Conv2D(1024, 3, activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
  ### A COMPLETER
  output = ...

  model = Model(input_layer, output)

  return model

# %%
model = create_model_YOLO()
model.summary()

# %% [markdown]
# ### Fonction de coût
#
# <center> <img src="https://drive.google.com/thumbnail?id=1Fbt_Wh_BqZj8Pwt3-04325ItCkQp5G9X&sz=w1000" style="width:500;height:300px;"></center>
# <caption><center> Détail de la fonction de perte définie dans l'article YOLO v1 </center></caption>
#
# Nous arrivons maintenant à la partie délicate de l'implémentation de YOLO : la définition de la fonction de coût à utiliser. En effet cette fonction de coût, qui sera appelée pendant l'entraînement, traitera des tenseurs et non des tableau *numpy*. On doit donc utiliser la librairie Tensorflow qui permet de manipuler les tenseurs. Les fonctions dont vous aurez besoin sont décrites majoritairement sur [cette page](https://www.tensorflow.org/api_docs/python/tf/math), ainsi qu'[ici](https://www.tensorflow.org/api_docs/python/tf/nn).
#
# Une partie essentielle de la fonction est déjà écrite (fonction YOLO_loss) : celle qui permet de séparer les données des cellules dites "vide" (la vérité terrain ne contient pas de boîte englobante) des "non vides". Cette fonction est apelée en première, et fait appel aux 3 sous-fonctions box_loss, coord_loss, et nobox_loss que vous devez compléter.
#
# Le détail de la fonction de coût est indiqué ci-dessus : dans l'article $\lambda_{\text{coord}} = 5$ et $\lambda_{\text{noobj}} = 0.5$. Les $x_i$, $y_i$, $w_i$, $h_i$ correspondent aux coordonnées d'une boîte englobante, $C_i$ correspond à la probabilité de présence d'un objet dans la cellule, et les $p_i(c)$ sont les probabilités de classe.
#
# A vous de compléter l'expression des sous-fonctions de la fonction de coût. **N'oubliez pas d'appliquer une sigmoïde aux présences ($C_i$) et une softmax aux probabilités de classe $p_i$) !!**
#
# **NB : cette implémentation de la fonction de coût est très simplifiée et prend en compte le fait qu'il n'y a qu'une seule boîte englobante par cellule.**
#
# **NB 2: la fonction tf.math.sqrt peut retourner NaN si elle est appelée sur une entrée négative. Un fix qui fonctionne est d'écrire tf.math.sqrt(tf.maximum(x, 1e-9)) pour qu'elle retourne une valeur proche de 0 plutôt que NaN.**

# %%
from keras import backend as K
import tensorflow as tf

### A COMPLETER
# Définition de la fonction de perte YOLO
def YOLOss(lambda_coord, lambda_noobj, batch_size):

    # Partie "verte" : sous-partie concernant l'indice de confiance et les
    # probabilités de classe dans le cas où une boîte est présente dans la cellule
    def box_loss(y_true, y_pred):
      return ...

    # Partie "bleue" : sous-partie concernant les coordonnées de boîte englobante
    # dans le cas où une boîte est présente dans la cellule
    def coord_loss(y_true, y_pred):
      return ...


    # Partie "rouge" : sous-partie concernant l'indice de confiance
    # dans le cas où aucune boîte n'est présente dans la cellule
    def nobox_loss(y_true, y_pred):
      return ...


    def YOLO_loss(y_true, y_pred):

      # On commence par reshape les tenseurs de bs x S x S x (5B+C) à (bsxSxS) x (5B+C)
      y_true = tf.reshape(y_true, [-1, 9])
      y_pred = tf.reshape(y_pred, [-1, 9])

      # On cherche (dans les labels y_true) les indices des cellules pour lesquelles au moins la première boîte englobante est présente
      not_empty = tf.math.greater_equal(y_true[:, 0], tf.constant([1.0]))
      indices = tf.range(tf.shape(y_true)[0])
      indices_notempty_cells = indices[not_empty]

      empty = tf.math.less_equal(y_true[:, 0], tf.constant([0.0]))
      indices_empty_cells = indices[empty]

      # On sépare les cellules de y_true et y_pred avec ou sans boîte englobante
      y_true_notempty = tf.gather(y_true, indices_notempty_cells)
      y_pred_notempty = tf.gather(y_pred, indices_notempty_cells)

      y_true_empty = tf.gather(y_true, indices_empty_cells)
      y_pred_empty = tf.gather(y_pred, indices_empty_cells)


      return (box_loss(y_true_notempty, y_pred_notempty) + lambda_coord*coord_loss(y_true_notempty, y_pred_notempty) + lambda_noobj*nobox_loss(y_true_empty, y_pred_empty))/batch_size


    # Return a function
    return YOLO_loss

# %% [markdown]
# ### Apprentissage
#
# Comme d'habitude, on sépare nos données en plusieurs ensembles (ici apprentissage et validation suffiront).

# %%
# Séparation des données en ensemble de validation et d'apprentissage
indices = np.arange(x.shape[0], dtype='int')
np.random.seed(1)
np.random.shuffle(indices)

x_train = x[indices[:1355]]
y_train = [y[i] for i in indices[:1355]]

x_val = x[indices[1355:]]
y_val = [y[i] for i in indices[1355:]]

y_val_YOLO = set_box_for_yolo(y_val)

# %% [markdown]
# Prenez le temps de tester votre modèle et votre fonction de coût, ainsi que vos réglages d'hyperparamètres, en sur-apprenant sur une image d'abord, puis sur un batch d'images. Entraînez votre réseau et visualisez ses prédictions sur les données d'entraînement, puis de validation, pour obtenir une intuition sur les valeurs de *loss* permettant d'obtenir des résultats "acceptables".

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

batch_size=16
model = create_model_YOLO()
opt = Adam(learning_rate=3e-4) # NB : n'hésitez pas à tester d'autres valeurs de learning rate

train_gen = YOLOSequence(x_train, y_train, batch_size, augmentations=AUGMENTATIONS_TRAIN)

# Comme l'entraînement est instable, on déclenche une sauvegarde du modèle à chaque fois que
# la perte de validation atteint un nouveau minimum
model_saver = ModelCheckpoint('tmp/best_weights', monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

loss=[YOLOss(5, 0.5, batch_size)]

model.compile(loss=loss,
              optimizer=opt)

history = model.fit(train_gen,
              epochs=150,
              batch_size=batch_size,
              validation_data=(x_val/255, y_val_YOLO),
              callbacks = [model_saver])

# %% [markdown]
# ### Test et affichage des résultats
#
# #### Test de la version à l'issue de l'entraînement
#
# **Sur l'ensemble d'apprentissage**

# %%
y_pred = model.predict(x_train/255)
y_pred_YOLO = get_box_from_yolo(y_pred, confidence_threshold=0.3, mode='pred')
print_data_detection(x_train, y_pred_YOLO)

# %%
print_data_detection(x_train, y_pred_YOLO)

# %% [markdown]
# **Sur l'ensemble de validation**

# %%
y_pred = model.predict(x_val/255)
y_pred_YOLO = get_box_from_yolo(y_pred, confidence_threshold=0.5, mode='pred')
print_data_detection(x_val, y_pred_YOLO)

# %%
print_data_detection(x_val, y_pred_YOLO)

# %% [markdown]
# #### Test de la meilleure version sauvegardée
#
# La cellule ci-dessous vous permettra de charger les poids sauvegardés lorsque la meilleur performance a été atteinte sur l'ensemble de validation pendant l'entraînement.

# %%
model.load_weights('tmp/best_weights')

# %% [markdown]
# **Sur l'ensemble d'apprentissage**

# %%
y_pred = model.predict(x_train/255)
y_pred_YOLO = get_box_from_yolo(y_pred, confidence_threshold=0.3, mode='pred')
print_data_detection(x_train, y_pred_YOLO)

# %%
print_data_detection(x_train, y_pred_YOLO)

# %% [markdown]
# **Sur l'ensemble de validation**

# %%
y_pred = model.predict(x_val/255)
y_pred_YOLO = get_box_from_yolo(y_pred, confidence_threshold=0.3, mode='pred')
print_data_detection(x_val, y_pred_YOLO)

# %%
print_data_detection(x_val, y_pred_YOLO)
